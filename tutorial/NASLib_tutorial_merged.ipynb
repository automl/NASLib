# %% [markdown]
# #NASLib Hands-On
#
# ##Welcome to the [NASLib](https://github.com/automl/NASLib) tutorial 📖
#
# Awesome to have you here!
#
# This notebook is part of the **NASLib Hands-On Session** for the [2nd AutoML Fall school](https://sites.google.com/view/automl-fall-school-2022). Before you start, please copy this notebook to your Google drive (`File` ➡ `Save a Copy in Drive`).

# %% [markdown]
# #[NASLib](https://github.com/automl/NASLib/) overview 🗒
# NASLib is a modular and flexible framework created with the aim of providing a common codebase to the community to facilitate research on Neural Architecture Search (NAS). It offers high-level abstractions for designing and reusing search spaces, interfaces to benchmarks and evaluation pipelines, enabling the implementation and extension of several NAS methods with a few lines of code.
#
# ![](https://raw.githubusercontent.com/automl/NASLib/Develop_copy/images/naslib-overall.png)

# %% [markdown]
# This tutorial will focus on Neural Architecture Search and how NASLib can be leveraged to simplify it greatly.
#
# The tutorial is divided into 4 sections:
# 1. [Setting up NASLib](#setup)
# 2. [Search Spaces in NASLib](#search_spaces)
# 3. [Optimizers in NASLib](#optimizers)
# 4. [Zero Cost Predictors in NASLib](#zcps)

# %% [markdown]
# <a name="setup"></a>
# # 1. Setting Up NASLib 💻
#
# We begin by setting up NASLib. First we, clone the repository and install NASLib.

# %%
#Setup NASLib
# %cd /content
# %rm -rf NASLib
# !git clone -b Develop_copy https://github.com/automl/NASLib/
# %cd /content/NASLib
# !pip install -e . --quiet
# Out:
# /content
# Cloning into 'NASLib'...
# remote: Enumerating objects: 32063, done.
# remote: Counting objects: 100% (2032/2032), done.
# remote: Compressing objects: 100% (824/824), done.
# remote: Total 32063 (delta 1253), reused 1913 (delta 1156), pack-reused 30031
# Receiving objects: 100% (32063/32063), 549.33 MiB | 24.06 MiB/s, done.
# Resolving deltas: 100% (22647/22647), done.
# /content/NASLib
#      |████████████████████████████████| 636 kB 5.2 MB/s
#      |████████████████████████████████| 49 kB 5.9 MB/s
#      |████████████████████████████████| 280 kB 57.9 MB/s
#      |████████████████████████████████| 2.0 MB 59.3 MB/s
#      |████████████████████████████████| 166.7 MB 16 kB/s
#      |████████████████████████████████| 45 kB 3.6 MB/s
#      |████████████████████████████████| 1.6 MB 40.3 MB/s
#      |████████████████████████████████| 634 kB 63.7 MB/s
#      |████████████████████████████████| 75 kB 4.4 MB/s
#      |████████████████████████████████| 13.5 MB 34.1 MB/s
#      |████████████████████████████████| 187 kB 85.3 MB/s
#      |████████████████████████████████| 1.4 MB 59.0 MB/s
#      |████████████████████████████████| 15.7 MB 35.6 MB/s
#      |████████████████████████████████| 42 kB 951 kB/s
#      |████████████████████████████████| 154 kB 57.8 MB/s
#      |████████████████████████████████| 349 kB 53.6 MB/s
#      |████████████████████████████████| 133 kB 61.4 MB/s
#      |████████████████████████████████| 77 kB 5.9 MB/s
#      |████████████████████████████████| 1.6 MB 65.1 MB/s
#   Building wheel for fvcore (setup.py) ... done
#   Building wheel for pybnn (setup.py) ... done
#   Building wheel for tensorwatch (setup.py) ... done
#   Building wheel for iopath (setup.py) ... done
#   Building wheel for autograd-gamma (setup.py) ... done
#   Building wheel for pydotz (setup.py) ... done
#   Building wheel for transforms3d (setup.py) ... done
# WARNING: Error parsing requirements for lightgbm: [Errno 2] No such file or directory: '/usr/local/lib/python3.7/dist-packages/lightgbm-2.2.3.dist-info/METADATA'
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.1.2 requires typing-extensions<4.2.0,>=3.7.4.1; python_version < "3.8", but you have typing-extensions 4.4.0 which is incompatible.
# spacy 3.4.1 requires typing-extensions<4.2.0,>=3.7.4; python_version < "3.8", but you have typing-extensions 4.4.0 which is incompatible.
# confection 0.0.2 requires typing-extensions<4.2.0,>=3.7.4.1; python_version < "3.8", but you have typing-extensions 4.4.0 which is incompatible.

# %% [markdown]
# You can ignore the pip errors relating to `typing-extensions`. Run the next cell to see if NASLib has been successfully installed.

# %%
import naslib

# %% [markdown]
# Next, we download a few datasets and benchmark files that we shall use in this notebook.

# %%
# Download benchmarks
# %cd /content/NASLib
# !source /content/NASLib/scripts/bash_scripts/download_benchmarks.sh nb201 cifar10
# !source /content/NASLib/scripts/bash_scripts/download_benchmarks.sh nb201 cifar100
# !source /content/NASLib/scripts/bash_scripts/download_benchmarks.sh nb201 ImageNet16-120
# !source /content/NASLib/scripts/bash_scripts/download_benchmarks.sh nb301 cifar10
# !source scripts/zc/bash_scripts/download_nbs_zero.sh nb201
# Out:
# /content/NASLib
# dataset = cifar10
# search_space = nb201
# cifar10 exists
# dataset = cifar100
# search_space = nb201
# cifar100 exists
# dataset = ImageNet16-120
# search_space = nb201
# Imagenet16 exists
# Imagenet16 data exits
# dataset = cifar10
# search_space = nb301
# nb301 full training pickle exists
# search_space = nb201
# nb201 file exist

# %% [markdown]
# If downloading the datasets using the script failed you can also download the data folder from [here](https://drive.google.com/file/d/1xjs6y2cf_mXKFjrT1auAynLMg48onQ5R/view?usp=sharing). If you need assistance, please let us know!
# Download and unzip the data folder and place its contents in `NASLib/naslib/data` using the commands below

# %%
#Caution: Run this cell only if downloading data using the script above fails
# %cd /content
# !gdown 1xjs6y2cf_mXKFjrT1auAynLMg48onQ5R
# !unzip -o data.zip 
# %ls
# %mv data/* /content/NASLib/naslib/data/
# %cd /content/NASLib/
# Out:
# /content
# Downloading...
# From: https://drive.google.com/uc?id=1xjs6y2cf_mXKFjrT1auAynLMg48onQ5R
# To: /content/data.zip
# 100% 383M/383M [00:01<00:00, 281MB/s]
# Archive:  data.zip
#   inflating: data/train_data_batch_1
#   inflating: __MACOSX/data/._train_data_batch_1
#   inflating: data/nb301_full_training.pickle
#   inflating: __MACOSX/data/._nb301_full_training.pickle
#   inflating: data/nb201_ImageNet16_full_training.pickle
#   inflating: __MACOSX/data/._nb201_ImageNet16_full_training.pickle
#   inflating: data/nb201_cifar10_full_training.pickle
#   inflating: __MACOSX/data/._nb201_cifar10_full_training.pickle
#   inflating: data/zc_nasbench201.json
#   inflating: __MACOSX/data/._zc_nasbench201.json
#   inflating: data/nb201_cifar100_full_training.pickle
#   inflating: __MACOSX/data/._nb201_cifar100_full_training.pickle
#   inflating: data/val_data
#   inflating: __MACOSX/data/._val_data
# data/  data.zip  __MACOSX/  NASLib/  sample_data/
# /content/NASLib

# %% [markdown]
# With that, setup is complete. We can now move on to the next section.

# %% [markdown]
# <a name="search_spaces"></a>
# # 2. Search Spaces in NASLib
# ### What is NAS Search Space?
# The search space defines which architectures can be represented using a choice of operations and topologies. Incorporating prior knowledge about typical properties of architectures well-suited for a task can reduce the size of the search space and simplify the search.However, this also introduces a human bias, which may prevent finding
# novel architectural building blocks that go beyond the current human knowledge.
#
# Let us consider the [NAS-Bench-201](https://arxiv.org/pdf/2001.00326.pdf) search space for example. This search space consists of multiple stacked cells. Each cell is a directed acyclic graph, and each operation selected from a predefined set of possible choices.
#
# ![](https://drive.google.com/uc?id=1Uw6InTaEWaE2gwgct6ztkLudEz7X3W2y)
#
# ### What is a NAS Benchmark?
# A NAS benchmark consits of the true or estimated performance of architectures from a NAS Search space each of which are evaluated on a fixed train-val-test aplit of the dataset and a fixed training pipeline. There are primarily two types of NAS benchmarks: a ***surrogate NAS benchmark*** and a ***tabular*** NAS benchmark.
#
# A surrogate benchmark uses a surrogate model (eg: a neural network) to predict the performance of an architecture from the search space. On the other hand a tabular benchmark queries the actual performance of an architecture trained upto convergence.
#
# ### Why do we need NAS Benchmarks?
#
# 1.   Neural architecture search often requires large computational resources. Evaluating a single model required one full training of a network
# 2.   Reproducibility in NAS research
#
# ###NASLib supports multiple search spaces and benchmarks like:
#
# 1. [NAS-Bench-101](https://arxiv.org/pdf/1902.09635.pdf)
# 2. [NAS-Bench-201](https://arxiv.org/pdf/2001.00326.pdf)
# 3. [NAS-Bench-301](https://arxiv.org/pdf/2008.09777.pdf)
# 4. [TransNAS-Bench-101](https://arxiv.org/pdf/2105.11871.pdf)
#
# ### With a unified API, NASLib allows you to trivially perform several operations, such as:
#
# 1. Sample a random model from the search space, which you can use as an actual PyTorch model
# 2. Query the Benchmark APIs of models for metrics such as training and validation accuracies
# 3. Convert between different representations of a given architecture
# 4. Mutate an architecture
#
# In the next part of the tutorial, we walk through each of these functionalities.

# %%
# Import the search space
# We begin by importing only the NAS-Bench-201 Search Space
from naslib.search_spaces import NasBench201SearchSpace
# Out:
# /usr/local/lib/python3.7/dist-packages/skimage/io/manage_plugins.py:23: UserWarning: Your installed pillow version is < 8.1.2. Several security issues (CVE-2021-27921, CVE-2021-25290, CVE-2021-25291, CVE-2021-25293, and more) have been fixed in pillow 8.1.2 or higher. We recommend to upgrade this library.
#   from .collection import imread_collection_wrapper

# %%
# Create a new search space object.
# This object doesn't have an architecture assigned to it yet - it represents the entire search space
graph = NasBench201SearchSpace(n_classes=10) # CIFAR-10 dataset requires 10 classes

# %%
# Sample a random architecture
# You can call this method only once on any instance
graph.sample_random_architecture()
graph.parse()

# Get the NASLib representation 
#(eg: operation index chosen at every edge) of the sampled architecture
graph.get_hash()
# Out:
# (0, 0, 3, 2, 1, 2)

# %%
# This graph is now a NAS-Bench-201 model, which can be used for training
# Forward pass some dummy data through it to see it in action

import torch

x = torch.randn(5, 3, 32, 32) # (Batch_size, Num_channels, Height, Width)

logits = graph(x)

print('Shape of the logits:', logits.shape)
# Out:
# Shape of the logits: torch.Size([5, 10])

# %%
# Import code to convert NASLib graph to the original NAS-Bench-201 representation
from naslib.search_spaces.nasbench201.conversions import convert_naslib_to_str as convert_naslib_nb201_to_str

# Get the string representation of this model, that the original authors of NAS-Bench-201 used
convert_naslib_nb201_to_str(graph)
# Out:
# '|skip_connect~0|+|skip_connect~0|nor_conv_3x3~1|+|nor_conv_1x1~0|none~1|nor_conv_3x3~2|'

# %%
# Mutating an architecture
# First, create a new child_graph
child_graph = NasBench201SearchSpace(n_classes=10)

# Call mutate on the child graph by passing the parent graph to it
child_graph.mutate(parent=graph)

# See the parent and child graph representations. Which edge was mutated?
print(f'Parent graph: {graph.get_hash()}')
print(f'Child graph : {child_graph.get_hash()}')
# Out:
# Parent graph: (0, 0, 3, 2, 1, 2)
# Child graph : (4, 0, 3, 2, 1, 2)

# %%
# Now, let's load the queryable tabular NAS-Bench-201 API
# This API has the training metrics of all the 15625 models in the search space
# such as train and validation accuracies/losses at every epoch

from naslib.utils import get_dataset_api
benchmark_api = get_dataset_api(search_space='nasbench201', dataset='cifar10')

# %%
# With the NAS-Bench-201 API, we can now query, say, the validation performance of any NB201 model
# Without it, we would have to train the model from scratch to get this information

# First, import the Metric enum
from naslib.search_spaces.core import Metric

# Metric has, among others, these values:
# Metric.TRAIN_ACCURACY
# Metric.VAL_ACCURACY
# Metric.TRAIN_LOSS
# Metric.TEST_LOSS
# Metric.TRAIN_TIME

train_acc_parent = graph.query(metric=Metric.TRAIN_ACCURACY, dataset='cifar10', dataset_api=benchmark_api)
val_acc_parent = graph.query(metric=Metric.VAL_ACCURACY, dataset='cifar10', dataset_api=benchmark_api)

print('Performance of parent model')
print(f'Train accuracy: {train_acc_parent:.2f}%')
print(f'Validation accuracy: {val_acc_parent:.2f}%')
# Out:
# Performance of parent model
# Train accuracy: 99.97%
# Validation accuracy: 89.27%

# %% [markdown]
# #Task 1: Play with NAS-Bench-301 (10 minutes)
#
# Now that you are familiar with the operations search spaces in NASLib, we can attempt our first task. In this task, you should do the following:
#
# 1. Sample a random NAS-Bench-301 model
# 2. Get the NASLib and genotype representations of the model
# 3. Query the predicted performance of the model (loading the NB301 benchmark API might take some time)
# 4. Mutate the model
# 5. Get the NASLib and genotype representations of the model
# 6. Query the predicted performance of the child
#
# All the modules you require are already imported for you.

# %%
from naslib.search_spaces import NasBench301SearchSpace
from naslib.search_spaces.nasbench301.conversions import convert_naslib_to_genotype as convert_naslib_nb301_to_genotype

########## START TODO ############
# TODO: 
# 1. Sample a random NAS-Bench-301 model
# 2. Get the NASLib and genotype representations of the model
# 3. Query the predicted performance of the model (loading the NB301 benchmark API might take some time)
# 4. Mutate the model
# 5. Get the NASLib and genotype representations of the model
# 6. Query the predicted performance of the child



########## END TODO ##############

# %% [markdown]
# <a name="optimizers"></a>
# ## 3. NAS Optimizers 📈
#
# ## What is a NAS Optimizer?
# The search strategy details how to explore the search space to find
# well-performing architectures quickly.
#
# ![](https://drive.google.com/uc?id=1e7a4LI-f7embNqUq23FwlysP6mQu63nx)
#
# Given the different NAS benchmarks we now want to search for the optimal architectures from the search spaces. NASLib provides a uniform api to use multiple optimizers across different benchmarks. One could easily write their own optimizer and evaluate it across the different NAS benchmarks.
#
# ## What is a performance predictor?
# Performance Estimation in NAS refers to estimating the performance of a given architecture. One trivial example of this is training a candidate architecture to convergence, but this can get very expensive. Much recent research therefore focuses on developing methods that reduce the cost of these performance estimations. A [performance predictor](https://arxiv.org/pdf/2104.01177.pdf) is defined generally as any function which predicts the final accuracy or ranking of architectures, without fully training the architectures (eg: xgboost)
#
# Some of the optimizers supported in NASLib are:
#
#
# 1.   [Random search](https://arxiv.org/pdf/1902.07638.pdf)
# 2.   [Local Search](https://arxiv.org/pdf/2004.08996.pdf)
# 3.   [Regularized Evolution](https://arxiv.org/pdf/1802.01548.)
# 4.   [BANANAS](https://arxiv.org/pdf/1910.11858.pdf)
#
# In this section of the tutorial we will walk through the following components:
#
#
# 1. Searching for an architecture using [Random search (RS)](https://arxiv.org/pdf/1902.07638.pdf) on different NAS benchmarks.
# 2. Searching for an architecture using [Regularized Evolution (RE)](https://arxiv.org/pdf/1802.01548.pdf) and comparing it with RS
# 3. Searching for an architecture using [BANANAS](https://arxiv.org/pdf/1910.11858.pdf) and comparing with RE and RS.

# %%
# The functions below setup and run the search experiments

def update_config(config, optimizer_type, search_space_type, dataset, seed):
    # Dataset being used
    config.dataset = dataset
    
    # Directory to which the results/logs will be saved
    config.save = f"runs/{optimizer_type.__name__}/{search_space_type.__name__}/{dataset}/{seed}"
    
    # Seed used during search phase of the optimizer
    config.search.seed = seed
    
def run_optimizer(optimizer_type, search_space_type, dataset, config, seed): 
    # Update the config
    update_config(config, optimizer_type, search_space_type, dataset, seed)

    # Make the results directories
    os.makedirs(config.save + '/search', exist_ok=True)
    os.makedirs(config.save + '/eval', exist_ok=True)

    # Set up the loggers
    logger = setup_logger()
    logger.setLevel(logging.INFO)

     # See the config
    logger.info(f'Configuration is \n{config}')

    # Set up the seed
    utils.set_seed(seed)
    # Instantiate the search space
    n_classes = {
        'cifar10': 10,
        'cifar100': 100,
        'ImageNet16-120': 120
    }
    search_space = search_space_type(n_classes=n_classes[dataset])
    search_space.instantiate_model = False
    # Get the benchmark API
    logger.info('Loading Benchmark API')
    dataset_api = get_dataset_api(search_space.get_type(), dataset)
    
    # Instantiate the optimizer and adapat the search space to the optimizer
    optimizer = optimizer_type(config)
    optimizer.adapt_search_space(search_space, dataset_api=dataset_api)

    # Create a Trainer
    trainer = Trainer(optimizer, config)

    # Perform the search
    trainer.search(report_incumbent=False)

    # Get the results of the search
    search_trajectory = trainer.search_trajectory
    print('Train accuracies:', search_trajectory.train_acc)
    print('Validation accuracies:', search_trajectory.valid_acc)
    # Get the validation performance of the best model found in the search phase
    best_model_val_acc = trainer.evaluate(dataset_api=dataset_api, metric=Metric.VAL_ACCURACY)
    best_model_val_acc

    best_model = optimizer.get_final_architecture()

    return search_trajectory, best_model, best_model_val_acc

# %%
# Defining plotting utils

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import sys
import os
import numpy as np
import json
import matplotlib.pyplot as plt
import pickle
import pandas as pd
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
from matplotlib.ticker import FormatStrFormatter

# plot performance vs runtime

# didn't run them long enough to do logspace here. (These experiments took surprisingly long to run)
plt.rcParams['axes.grid'] = True
plt.rcParams['grid.linestyle'] = 'dotted'
# set up colors and plot markings
defaults = [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
            (1.0, 0.4980392156862745, 0.054901960784313725),
            (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
            (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
            (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
            (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
            (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
            (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
            (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
            (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# goes up to 24
c_max = 9
colors = [*defaults[:c_max], *defaults[:c_max], *defaults[:c_max]]
fmts = [*['-'] * c_max, *['--'] * c_max, *[':'] * c_max]
markers = [*['^'] * c_max, *['v'] * c_max, *['o'] * c_max]


def get_results(results, metric='valid_acc', dataset='cifar10', ug=False):
    output = []
    time = []
    for result in results:
        val_acc = result['valid_acc']
        surr_time = np.array(result['runtime'])
        if ug:
            runtime = 200 * np.array(result['train_time']) + surr_time
        else:
            runtime = np.array(result['train_time']) + surr_time
        val_err = [100 - x for x in val_acc]
        val_incumbent = [
            min(val_err[:epoch]) for epoch in range(1,
                                                    len(val_err) + 1)
        ]
        runtime = [
            sum(runtime[:epoch]) for epoch in range(1,
                                                    len(runtime) + 1)
        ]
        if metric == 'valid_acc':
            incumbent = val_incumbent
        elif metric == 'test_acc':
            test_err = [100 - x for x in result['test_acc']]
            inc_idx, best, best_idx = [], np.inf, 0
            for i, err in enumerate(val_err):
                if err < best:
                    best, best_idx = err, i
                    inc_idx.append(best_idx)
                    incumbent = [test_err[idx] for idx in inc_idx]
        output.append(incumbent)
        time.append(runtime)
    output = np.array(output)
    time = np.array(runtime)
    mean = np.mean(output, axis=0)
    std = np.std(output, axis=0)
    std_error = np.sqrt(
        np.var(output, axis=0, ddof=1) / np.asarray(output).shape[0])
    return mean, std, std_error, time


def plot_optimizers(trajectories,benchmark):
    plot_zoomed = False
    plot_sem = True
    fig, ax = plt.subplots(figsize=[10, 5])
    if plot_zoomed:
        sub_axes = plt.axes([.6, .6, .25, .25])
    i = 0
    for optimizer in trajectories.keys():
        mean, std, std_error, time = get_results(trajectories[optimizer])
        results_dict = {}
        results_dict = {
            'label': optimizer,
            'mean': mean,
            'runtime': time,
            'std_error': std_error
        }
        mean = results_dict['mean']
        #print(mean.shape)
        x = results_dict['runtime']
        #print(x.shape)
        sem = results_dict['std_error']
        #print(sem.shape)
        label = results_dict["label"]
        ax.plot(x, mean, label=label, color=colors[i], linestyle=fmts[i])
        ax.fill_between(x,
                        mean - 1 * sem,
                        mean + 1 * sem,
                        color=colors[i],
                        alpha=0.2)
        i = i + 1
    ax.yaxis.set_major_formatter(FormatStrFormatter('%.3f'))
    ax.set_xscale('log')
    ax.legend(loc=(1.04, 0))
    ax.set_xlabel('Runtime [s] (simulated)')
    ax.set_ylabel('Test error (%)')
    ax.grid(True, which="both", ls="-", alpha=.5)
    ax.set_title('Test error vs. train time on '+benchmark)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Random Search
# 1. Sample an architecture for every epoch and compute its validation error
# 2. Select the architecture with the lowest validation error and return its test error

# %%
#initialize trajectories for RS
trajectories_rs = {}

# %%
#imports we will use throught this section
import json
import logging
import os

# import the Trainer used to run the optimizer on a given search space
from naslib.defaults.trainer import Trainer
# import the optimizers
from naslib.optimizers import (
    RandomSearch,
    RegularizedEvolution,
    Bananas
)
# import the search spaces
from naslib.search_spaces import (
    NasBench101SearchSpace,
    NasBench201SearchSpace,
    NasBench301SearchSpace,
)

from naslib.search_spaces.core.query_metrics import Metric
from naslib import utils
from naslib.utils import get_dataset_api
from naslib.utils.logging import setup_logger

from fvcore.common.config import CfgNode

# %%
# Set the optimizer and search space types
# They will be instantiated inside run_optimizer
optimizer_type = RandomSearch # {RegularizedEvolution, RandomSearch}
search_space_type = NasBench201SearchSpace # {NasBench101SearchSpace, NasBench201SearchSpace, NasBench301SearchSpace}

# Set the dataset
dataset = 'cifar10' # cifar10 for NB101 and NB301, {cifar100, ImageNet16-120} for NB201

# The configuration used by the Trainer and Optimizer
# The missing information will be populated inside run_optimizer
config = {
    'search': {
        # Required by Trainer
        'epochs': 100,
        'checkpoint_freq': 200,
        
        # Required by Random Search optimizer
        'fidelity': -1,
        
        # Required by RegularizedEvolution
        'sample_size': 10,
        'population_size': 30,
    }
}
config = CfgNode.load_cfg(json.dumps(config))
#Initialize trajectories for the 3 seeds
trajectories_rs["RS"] = []
for seed in [333,444,555]: #Run RS for 3 seeds
  search_trajectory, best_model, best_model_val_acc = run_optimizer(
                                                        optimizer_type,
                                                        search_space_type,
                                                        dataset,
                                                        config,
                                                        seed
                                                    )
  trajectories_rs["RS"].append(search_trajectory)
# Out:
# [10/08 11:21:52 naslib]: Configuration is
# dataset: cifar10
# save: runs/RandomSearch/NasBench201SearchSpace/cifar10/333
# search:
#   checkpoint_freq: 200
#   epochs: 100
#   fidelity: -1
#   population_size: 30
#   sample_size: 10
#   seed: 333
# [10/08 11:21:52 naslib]: Loading Benchmark API
# [10/08 11:21:54 nl.defaults.trainer]: Beginning search
# [10/08 11:21:54 nl.defaults.trainer]: Epoch 0 done. Train accuracy: 99.54800, Validation accuracy: 83.83000
# [10/08 11:21:54 nl.defaults.trainer]: Epoch 1 done. Train accuracy: 72.61200, Validation accuracy: 66.22000
# [10/08 11:21:54 nl.defaults.trainer]: Epoch 2 done. Train accuracy: 99.91200, Validation accuracy: 88.09000
# [10/08 11:21:54 nl.defaults.trainer]: Epoch 3 done. Train accuracy: 99.88400, Validation accuracy: 88.68000
# [10/08 11:21:54 nl.defaults.trainer]: Epoch 4 done. Train accuracy: 99.92000, Validation accuracy: 89.14000
# [10/08 11:21:54 nl.defaults.trainer]: Epoch 5 done. Train accuracy: 99.98800, Validation accuracy: 90.01000
# [10/08 11:21:54 nl.defaults.trainer]: Epoch 6 done. Train accuracy: 97.94400, Validation accuracy: 85.91000
# [10/08 11:21:55 nl.defaults.trainer]: Epoch 7 done. Train accuracy: 89.03200, Validation accuracy: 81.87000
# [10/08 11:21:55 nl.defaults.trainer]: Epoch 8 done. Train accuracy: 72.39200, Validation accuracy: 66.30000
# [10/08 11:21:55 nl.defaults.trainer]: Epoch 9 done. Train accuracy: 99.52800, Validation accuracy: 87.35000
# [10/08 11:21:55 nl.defaults.trainer]: Epoch 10 done. Train accuracy: 91.91600, Validation accuracy: 83.42000
# [10/08 11:21:55 nl.defaults.trainer]: Epoch 11 done. Train accuracy: 99.98000, Validation accuracy: 87.95000
# [10/08 11:21:55 nl.defaults.trainer]: Epoch 12 done. Train accuracy: 99.95200, Validation accuracy: 89.08000
# [10/08 11:21:55 nl.defaults.trainer]: Epoch 13 done. Train accuracy: 99.33600, Validation accuracy: 85.22000
# [10/08 11:21:56 nl.defaults.trainer]: Epoch 14 done. Train accuracy: 96.72400, Validation accuracy: 85.97000
# [10/08 11:21:56 nl.defaults.trainer]: Epoch 15 done. Train accuracy: 99.68400, Validation accuracy: 87.61000
# [10/08 11:21:56 nl.defaults.trainer]: Epoch 16 done. Train accuracy: 99.75200, Validation accuracy: 87.90000
# [10/08 11:21:56 nl.defaults.trainer]: Epoch 17 done. Train accuracy: 99.93200, Validation accuracy: 87.75000
# [10/08 11:21:56 nl.defaults.trainer]: Epoch 18 done. Train accuracy: 99.94800, Validation accuracy: 87.17000
# [10/08 11:21:56 nl.defaults.trainer]: Epoch 19 done. Train accuracy: 99.98400, Validation accuracy: 90.90000
# [10/08 11:21:56 nl.defaults.trainer]: Epoch 20 done. Train accuracy: 91.22000, Validation accuracy: 84.73000
# [10/08 11:21:57 nl.defaults.trainer]: Epoch 21 done. Train accuracy: 99.98800, Validation accuracy: 89.33000
# [10/08 11:21:57 nl.defaults.trainer]: Epoch 22 done. Train accuracy: 99.03600, Validation accuracy: 86.10000
# [10/08 11:21:58 nl.defaults.trainer]: Epoch 23 done. Train accuracy: 80.56400, Validation accuracy: 70.60000
# [10/08 11:21:58 nl.defaults.trainer]: Epoch 24 done. Train accuracy: 99.84400, Validation accuracy: 83.95000
# [10/08 11:21:58 nl.defaults.trainer]: Epoch 25 done. Train accuracy: 99.71200, Validation accuracy: 85.71000
# [10/08 11:21:58 nl.defaults.trainer]: Epoch 26 done. Train accuracy: 99.95600, Validation accuracy: 89.23000
# [10/08 11:21:58 nl.defaults.trainer]: Epoch 27 done. Train accuracy: 93.84800, Validation accuracy: 84.40000
# [10/08 11:21:58 nl.defaults.trainer]: Epoch 28 done. Train accuracy: 99.96800, Validation accuracy: 90.15000
# [10/08 11:21:58 nl.defaults.trainer]: Epoch 29 done. Train accuracy: 99.62000, Validation accuracy: 86.15000
# [10/08 11:21:59 nl.defaults.trainer]: Epoch 30 done. Train accuracy: 99.88800, Validation accuracy: 88.82000
# [10/08 11:21:59 nl.defaults.trainer]: Epoch 31 done. Train accuracy: 99.96400, Validation accuracy: 88.33000
# [10/08 11:21:59 nl.defaults.trainer]: Epoch 32 done. Train accuracy: 99.97200, Validation accuracy: 90.10000
# [10/08 11:22:00 nl.defaults.trainer]: Epoch 33 done. Train accuracy: 99.96400, Validation accuracy: 88.78000
# [10/08 11:22:00 nl.defaults.trainer]: Epoch 34 done. Train accuracy: 80.54000, Validation accuracy: 70.81000
# [10/08 11:22:00 nl.defaults.trainer]: Epoch 35 done. Train accuracy: 99.97600, Validation accuracy: 89.24000
# [10/08 11:22:00 nl.defaults.trainer]: Epoch 36 done. Train accuracy: 99.94800, Validation accuracy: 89.45000
# [10/08 11:22:00 nl.defaults.trainer]: Epoch 37 done. Train accuracy: 98.33200, Validation accuracy: 86.13000
# [10/08 11:22:01 nl.defaults.trainer]: Epoch 38 done. Train accuracy: 90.07600, Validation accuracy: 75.50000
# [10/08 11:22:01 nl.defaults.trainer]: Epoch 39 done. Train accuracy: 99.26800, Validation accuracy: 86.98000
# [10/08 11:22:01 nl.defaults.trainer]: Epoch 40 done. Train accuracy: 99.93200, Validation accuracy: 89.72000
# [10/08 11:22:01 nl.defaults.trainer]: Epoch 41 done. Train accuracy: 83.03200, Validation accuracy: 78.51000
# [10/08 11:22:01 nl.defaults.trainer]: Epoch 42 done. Train accuracy: 99.96800, Validation accuracy: 89.14000
# [10/08 11:22:01 nl.defaults.trainer]: Epoch 43 done. Train accuracy: 98.34400, Validation accuracy: 84.97000
# [10/08 11:22:01 nl.defaults.trainer]: Epoch 44 done. Train accuracy: 98.59200, Validation accuracy: 85.20000
# [10/08 11:22:02 nl.defaults.trainer]: Epoch 45 done. Train accuracy: 99.95200, Validation accuracy: 88.90000
# [10/08 11:22:02 nl.defaults.trainer]: Epoch 46 done. Train accuracy: 99.89200, Validation accuracy: 86.81000
# [10/08 11:22:03 nl.defaults.trainer]: Epoch 47 done. Train accuracy: 99.93600, Validation accuracy: 89.10000
# [10/08 11:22:03 nl.defaults.trainer]: Epoch 48 done. Train accuracy: 99.92000, Validation accuracy: 88.74000
# [10/08 11:22:03 nl.defaults.trainer]: Epoch 49 done. Train accuracy: 99.97200, Validation accuracy: 89.65000
# [10/08 11:22:03 nl.defaults.trainer]: Epoch 50 done. Train accuracy: 75.53600, Validation accuracy: 72.63000
# [10/08 11:22:03 nl.defaults.trainer]: Epoch 51 done. Train accuracy: 99.93600, Validation accuracy: 88.75000
# [10/08 11:22:04 nl.defaults.trainer]: Epoch 52 done. Train accuracy: 99.88800, Validation accuracy: 88.93000
# [10/08 11:22:04 nl.defaults.trainer]: Epoch 53 done. Train accuracy: 99.88400, Validation accuracy: 88.96000
# [10/08 11:22:04 nl.defaults.trainer]: Epoch 54 done. Train accuracy: 93.16000, Validation accuracy: 83.78000
# [10/08 11:22:04 nl.defaults.trainer]: Epoch 55 done. Train accuracy: 80.89600, Validation accuracy: 71.82000
# [10/08 11:22:04 nl.defaults.trainer]: Epoch 56 done. Train accuracy: 96.33600, Validation accuracy: 85.62000
# [10/08 11:22:04 nl.defaults.trainer]: Epoch 57 done. Train accuracy: 91.50400, Validation accuracy: 82.99000
# [10/08 11:22:04 nl.defaults.trainer]: Epoch 58 done. Train accuracy: 99.88000, Validation accuracy: 89.00000
# [10/08 11:22:05 nl.defaults.trainer]: Epoch 59 done. Train accuracy: 81.36800, Validation accuracy: 71.48000
# [10/08 11:22:05 nl.defaults.trainer]: Epoch 60 done. Train accuracy: 75.50000, Validation accuracy: 72.65000
# [10/08 11:22:05 nl.defaults.trainer]: Epoch 61 done. Train accuracy: 98.07200, Validation accuracy: 84.94000
# [10/08 11:22:05 nl.defaults.trainer]: Epoch 62 done. Train accuracy: 83.36800, Validation accuracy: 78.16000
# [10/08 11:22:05 nl.defaults.trainer]: Epoch 63 done. Train accuracy: 99.84800, Validation accuracy: 88.09000
# [10/08 11:22:06 nl.defaults.trainer]: Epoch 64 done. Train accuracy: 99.87600, Validation accuracy: 88.85000
# [10/08 11:22:07 nl.defaults.trainer]: Epoch 65 done. Train accuracy: 99.87600, Validation accuracy: 88.71000
# [10/08 11:22:07 nl.defaults.trainer]: Epoch 66 done. Train accuracy: 99.90400, Validation accuracy: 88.39000
# [10/08 11:22:07 nl.defaults.trainer]: Epoch 67 done. Train accuracy: 99.92800, Validation accuracy: 88.91000
# [10/08 11:22:07 nl.defaults.trainer]: Epoch 68 done. Train accuracy: 34.36800, Validation accuracy: 33.86000
# [10/08 11:22:07 nl.defaults.trainer]: Epoch 69 done. Train accuracy: 71.92400, Validation accuracy: 66.50000
# [10/08 11:22:07 nl.defaults.trainer]: Epoch 70 done. Train accuracy: 99.90000, Validation accuracy: 88.01000
# [10/08 11:22:07 nl.defaults.trainer]: Epoch 71 done. Train accuracy: 99.46400, Validation accuracy: 86.21000
# [10/08 11:22:08 nl.defaults.trainer]: Epoch 72 done. Train accuracy: 99.76400, Validation accuracy: 85.95000
# [10/08 11:22:08 nl.defaults.trainer]: Epoch 73 done. Train accuracy: 99.96400, Validation accuracy: 88.72000
# [10/08 11:22:08 nl.defaults.trainer]: Epoch 74 done. Train accuracy: 99.86800, Validation accuracy: 86.01000
# [10/08 11:22:08 nl.defaults.trainer]: Epoch 75 done. Train accuracy: 99.60800, Validation accuracy: 88.26000
# [10/08 11:22:08 nl.defaults.trainer]: Epoch 76 done. Train accuracy: 81.52400, Validation accuracy: 72.35000
# [10/08 11:22:08 nl.defaults.trainer]: Epoch 77 done. Train accuracy: 99.92400, Validation accuracy: 88.59000
# [10/08 11:22:09 nl.defaults.trainer]: Epoch 78 done. Train accuracy: 97.80800, Validation accuracy: 85.86000
# [10/08 11:22:09 nl.defaults.trainer]: Epoch 79 done. Train accuracy: 99.95200, Validation accuracy: 88.68000
# [10/08 11:22:09 nl.defaults.trainer]: Epoch 80 done. Train accuracy: 99.95600, Validation accuracy: 88.94000
# [10/08 11:22:09 nl.defaults.trainer]: Epoch 81 done. Train accuracy: 76.46800, Validation accuracy: 71.43000
# [10/08 11:22:09 nl.defaults.trainer]: Epoch 82 done. Train accuracy: 90.96800, Validation accuracy: 84.01000
# [10/08 11:22:10 nl.defaults.trainer]: Epoch 83 done. Train accuracy: 99.98800, Validation accuracy: 90.33000
# [10/08 11:22:10 nl.defaults.trainer]: Epoch 84 done. Train accuracy: 99.96400, Validation accuracy: 89.32000
# [10/08 11:22:12 nl.defaults.trainer]: Epoch 85 done. Train accuracy: 92.88000, Validation accuracy: 78.58000
# [10/08 11:22:13 nl.defaults.trainer]: Epoch 86 done. Train accuracy: 99.00800, Validation accuracy: 79.69000
# [10/08 11:22:13 nl.defaults.trainer]: Epoch 87 done. Train accuracy: 99.96400, Validation accuracy: 88.91000
# [10/08 11:22:13 nl.defaults.trainer]: Epoch 88 done. Train accuracy: 99.89200, Validation accuracy: 87.98000
# [10/08 11:22:13 nl.defaults.trainer]: Epoch 89 done. Train accuracy: 99.96400, Validation accuracy: 88.95000
# [10/08 11:22:13 nl.defaults.trainer]: Epoch 90 done. Train accuracy: 99.94800, Validation accuracy: 88.98000
# [10/08 11:22:13 nl.defaults.trainer]: Epoch 91 done. Train accuracy: 99.94400, Validation accuracy: 89.93000
# [10/08 11:22:13 nl.defaults.trainer]: Epoch 92 done. Train accuracy: 99.98800, Validation accuracy: 90.56000
# [10/08 11:22:13 nl.defaults.trainer]: Epoch 93 done. Train accuracy: 99.94000, Validation accuracy: 88.04000
# [10/08 11:22:14 nl.defaults.trainer]: Epoch 94 done. Train accuracy: 99.93600, Validation accuracy: 88.18000
# [10/08 11:22:14 nl.defaults.trainer]: Epoch 95 done. Train accuracy: 99.96000, Validation accuracy: 89.18000
# [10/08 11:22:14 nl.defaults.trainer]: Epoch 96 done. Train accuracy: 98.53600, Validation accuracy: 84.03000
# [10/08 11:22:14 nl.defaults.trainer]: Epoch 97 done. Train accuracy: 99.98400, Validation accuracy: 90.95000
# [10/08 11:22:14 nl.defaults.trainer]: Epoch 98 done. Train accuracy: 92.82800, Validation accuracy: 79.55000
# [10/08 11:22:14 nl.defaults.trainer]: Epoch 99 done. Train accuracy: 99.92000, Validation accuracy: 89.51000
# [10/08 11:22:14 nl.defaults.trainer]: Training finished
# Train accuracies: [99.548, 72.61199998291016, 99.912, 99.88400000244141, 99.92, 99.988, 97.94400000732422, 89.03200001220704, 72.39200001953125, 99.528, 91.91600001953125, 99.98, 99.952, 99.336, 96.72400001464844, 99.684, 99.75200000488282, 99.932, 99.948, 99.984, 91.21999999511719, 99.988, 99.03600000244141, 80.56399998779297, 99.84400000488282, 99.71200000488281, 99.956, 93.84799998046876, 99.968, 99.62, 99.888, 99.964, 99.972, 99.964, 80.54000000976562, 99.97600000244141, 99.948, 98.332, 90.07599999023438, 99.26800000244141, 99.932, 83.03200001220704, 99.968, 98.34400000732421, 98.59200000732422, 99.952, 99.892, 99.9360000024414, 99.92000000244141, 99.972, 75.53599999023437, 99.936, 99.888, 99.884, 93.15999998291015, 80.896, 96.33600000732422, 91.50399999023438, 99.88, 81.36800001464844, 75.50000000976563, 98.07200000976563, 83.36799998535156, 99.848, 99.876, 99.876, 99.9040000024414, 99.928, 34.368, 71.92399999023438, 99.9, 99.46400000244141, 99.76400000732421, 99.964, 99.86800000488282, 99.608, 81.52399997558594, 99.924, 97.80800000976562, 99.952, 99.956, 76.468, 90.96799999023438, 99.988, 99.964, 92.87999997802734, 99.00800000732421, 99.964, 99.892, 99.964, 99.948, 99.944, 99.988, 99.94, 99.936, 99.96, 98.53600001220703, 99.984, 92.82799999267579, 99.92]
# Validation accuracies: [83.83, 66.22, 88.09, 88.68, 89.14, 90.01, 85.91, 81.87, 66.3, 87.35, 83.42, 87.95, 89.08, 85.22, 85.97, 87.61, 87.9, 87.75, 87.17, 90.9, 84.73, 89.33, 86.1, 70.6, 83.95, 85.71, 89.23, 84.4, 90.15, 86.15, 88.82, 88.33, 90.1, 88.78, 70.81, 89.24, 89.45, 86.13, 75.5, 86.98, 89.72, 78.51, 89.14, 84.97, 85.2, 88.9, 86.81, 89.1, 88.74, 89.65, 72.63, 88.75, 88.93, 88.96, 83.78, 71.82, 85.62, 82.99, 89.0, 71.48, 72.65, 84.94, 78.16, 88.09, 88.85, 88.71, 88.39, 88.91, 33.86, 66.5, 88.01, 86.21, 85.95, 88.72, 86.01, 88.26, 72.35, 88.59, 85.86, 88.68, 88.94, 71.43, 84.01, 90.33, 89.32, 78.58, 79.69, 88.91, 87.98, 88.95, 88.98, 89.93, 90.56, 88.04, 88.18, 89.18, 84.03, 90.95, 79.55, 89.51]
# [10/08 11:22:14 nl.defaults.trainer]: Start evaluation
# [10/08 11:22:14 nl.defaults.trainer]: loading model from file runs/RandomSearch/NasBench201SearchSpace/cifar10/333/search/model_final.pth
# [10/08 11:22:14 nl.defaults.trainer]: Final architecture hash: (3, 2, 0, 0, 3, 2)
# [10/08 11:22:14 nl.defaults.trainer]: Queried results (Metric.VAL_ACCURACY): 90.95
# [10/08 11:22:15 naslib]: Configuration is
# dataset: cifar10
# save: runs/RandomSearch/NasBench201SearchSpace/cifar10/444
# search:
#   checkpoint_freq: 200
#   epochs: 100
#   fidelity: -1
#   population_size: 30
#   sample_size: 10
#   seed: 444
# [10/08 11:22:15 naslib]: Loading Benchmark API
# [10/08 11:22:16 nl.defaults.trainer]: Beginning search
# [10/08 11:22:16 nl.defaults.trainer]: Epoch 0 done. Train accuracy: 96.48400, Validation accuracy: 84.99000
# [10/08 11:22:16 nl.defaults.trainer]: Epoch 1 done. Train accuracy: 99.98400, Validation accuracy: 89.59000
# [10/08 11:22:17 nl.defaults.trainer]: Epoch 2 done. Train accuracy: 99.96400, Validation accuracy: 89.77000
# [10/08 11:22:17 nl.defaults.trainer]: Epoch 3 done. Train accuracy: 99.97200, Validation accuracy: 89.29000
# [10/08 11:22:18 nl.defaults.trainer]: Epoch 4 done. Train accuracy: 99.80400, Validation accuracy: 86.00000
# [10/08 11:22:18 nl.defaults.trainer]: Epoch 5 done. Train accuracy: 99.76800, Validation accuracy: 88.02000
# [10/08 11:22:18 nl.defaults.trainer]: Epoch 6 done. Train accuracy: 99.96000, Validation accuracy: 90.07000
# [10/08 11:22:18 nl.defaults.trainer]: Epoch 7 done. Train accuracy: 99.92000, Validation accuracy: 89.08000
# [10/08 11:22:18 nl.defaults.trainer]: Epoch 8 done. Train accuracy: 100.00000, Validation accuracy: 91.15000
# [10/08 11:22:18 nl.defaults.trainer]: Epoch 9 done. Train accuracy: 79.54000, Validation accuracy: 74.85000
# [10/08 11:22:18 nl.defaults.trainer]: Epoch 10 done. Train accuracy: 96.30000, Validation accuracy: 85.59000
# [10/08 11:22:18 nl.defaults.trainer]: Epoch 11 done. Train accuracy: 97.95200, Validation accuracy: 85.98000
# [10/08 11:22:19 nl.defaults.trainer]: Epoch 12 done. Train accuracy: 99.93600, Validation accuracy: 89.65000
# [10/08 11:22:19 nl.defaults.trainer]: Epoch 13 done. Train accuracy: 99.97200, Validation accuracy: 90.32000
# [10/08 11:22:20 nl.defaults.trainer]: Epoch 14 done. Train accuracy: 97.62400, Validation accuracy: 85.98000
# [10/08 11:22:20 nl.defaults.trainer]: Epoch 15 done. Train accuracy: 99.93600, Validation accuracy: 89.16000
# [10/08 11:22:20 nl.defaults.trainer]: Epoch 16 done. Train accuracy: 99.88400, Validation accuracy: 89.64000
# [10/08 11:22:20 nl.defaults.trainer]: Epoch 17 done. Train accuracy: 79.52400, Validation accuracy: 74.86000
# [10/08 11:22:20 nl.defaults.trainer]: Epoch 18 done. Train accuracy: 99.98400, Validation accuracy: 90.45000
# [10/08 11:22:20 nl.defaults.trainer]: Epoch 19 done. Train accuracy: 99.24400, Validation accuracy: 84.74000
# [10/08 11:22:20 nl.defaults.trainer]: Epoch 20 done. Train accuracy: 99.97200, Validation accuracy: 90.22000
# [10/08 11:22:21 nl.defaults.trainer]: Epoch 21 done. Train accuracy: 96.60400, Validation accuracy: 85.90000
# [10/08 11:22:21 nl.defaults.trainer]: Epoch 22 done. Train accuracy: 99.48800, Validation accuracy: 87.33000
# [10/08 11:22:22 nl.defaults.trainer]: Epoch 23 done. Train accuracy: 80.86000, Validation accuracy: 71.42000
# [10/08 11:22:22 nl.defaults.trainer]: Epoch 24 done. Train accuracy: 99.91200, Validation accuracy: 88.61000
# [10/08 11:22:22 nl.defaults.trainer]: Epoch 25 done. Train accuracy: 99.68400, Validation accuracy: 86.31000
# [10/08 11:22:22 nl.defaults.trainer]: Epoch 26 done. Train accuracy: 99.92800, Validation accuracy: 88.26000
# [10/08 11:22:22 nl.defaults.trainer]: Epoch 27 done. Train accuracy: 81.22400, Validation accuracy: 77.46000
# [10/08 11:22:22 nl.defaults.trainer]: Epoch 28 done. Train accuracy: 98.56000, Validation accuracy: 86.44000
# [10/08 11:22:22 nl.defaults.trainer]: Epoch 29 done. Train accuracy: 81.10000, Validation accuracy: 71.41000
# [10/08 11:22:23 nl.defaults.trainer]: Epoch 30 done. Train accuracy: 82.50400, Validation accuracy: 77.88000
# [10/08 11:22:23 nl.defaults.trainer]: Epoch 31 done. Train accuracy: 99.98400, Validation accuracy: 89.97000
# [10/08 11:22:23 nl.defaults.trainer]: Epoch 32 done. Train accuracy: 99.95600, Validation accuracy: 88.36000
# [10/08 11:22:23 nl.defaults.trainer]: Epoch 33 done. Train accuracy: 99.62800, Validation accuracy: 86.50000
# [10/08 11:22:24 nl.defaults.trainer]: Epoch 34 done. Train accuracy: 91.44800, Validation accuracy: 82.42000
# [10/08 11:22:24 nl.defaults.trainer]: Epoch 35 done. Train accuracy: 71.94000, Validation accuracy: 66.15000
# [10/08 11:22:24 nl.defaults.trainer]: Epoch 36 done. Train accuracy: 81.19200, Validation accuracy: 71.82000
# [10/08 11:22:24 nl.defaults.trainer]: Epoch 37 done. Train accuracy: 99.82800, Validation accuracy: 87.97000
# [10/08 11:22:25 nl.defaults.trainer]: Epoch 38 done. Train accuracy: 99.82000, Validation accuracy: 85.67000
# [10/08 11:22:25 nl.defaults.trainer]: Epoch 39 done. Train accuracy: 99.89600, Validation accuracy: 86.79000
# [10/08 11:22:25 nl.defaults.trainer]: Epoch 40 done. Train accuracy: 99.96400, Validation accuracy: 89.26000
# [10/08 11:22:25 nl.defaults.trainer]: Epoch 41 done. Train accuracy: 91.65200, Validation accuracy: 83.89000
# [10/08 11:22:25 nl.defaults.trainer]: Epoch 42 done. Train accuracy: 99.92800, Validation accuracy: 88.43000
# [10/08 11:22:25 nl.defaults.trainer]: Epoch 43 done. Train accuracy: 80.97200, Validation accuracy: 71.87000
# [10/08 11:22:25 nl.defaults.trainer]: Epoch 44 done. Train accuracy: 99.46400, Validation accuracy: 86.21000
# [10/08 11:22:26 nl.defaults.trainer]: Epoch 45 done. Train accuracy: 99.92800, Validation accuracy: 88.60000
# [10/08 11:22:26 nl.defaults.trainer]: Epoch 46 done. Train accuracy: 99.56000, Validation accuracy: 87.40000
# [10/08 11:22:26 nl.defaults.trainer]: Epoch 47 done. Train accuracy: 99.91200, Validation accuracy: 87.21000
# [10/08 11:22:26 nl.defaults.trainer]: Epoch 48 done. Train accuracy: 99.98000, Validation accuracy: 90.99000
# [10/08 11:22:27 nl.defaults.trainer]: Epoch 49 done. Train accuracy: 99.91600, Validation accuracy: 88.84000
# [10/08 11:22:27 nl.defaults.trainer]: Epoch 50 done. Train accuracy: 99.84000, Validation accuracy: 88.38000
# [10/08 11:22:27 nl.defaults.trainer]: Epoch 51 done. Train accuracy: 90.82800, Validation accuracy: 83.78000
# [10/08 11:22:28 nl.defaults.trainer]: Epoch 52 done. Train accuracy: 99.84400, Validation accuracy: 86.73000
# [10/08 11:22:28 nl.defaults.trainer]: Epoch 53 done. Train accuracy: 99.90800, Validation accuracy: 88.97000
# [10/08 11:22:28 nl.defaults.trainer]: Epoch 54 done. Train accuracy: 99.93600, Validation accuracy: 89.04000
# [10/08 11:22:28 nl.defaults.trainer]: Epoch 55 done. Train accuracy: 89.90400, Validation accuracy: 71.76000
# [10/08 11:22:28 nl.defaults.trainer]: Epoch 56 done. Train accuracy: 99.60000, Validation accuracy: 87.68000
# [10/08 11:22:28 nl.defaults.trainer]: Epoch 57 done. Train accuracy: 99.27200, Validation accuracy: 83.42000
# [10/08 11:22:28 nl.defaults.trainer]: Epoch 58 done. Train accuracy: 90.77600, Validation accuracy: 81.19000
# [10/08 11:22:29 nl.defaults.trainer]: Epoch 59 done. Train accuracy: 99.96800, Validation accuracy: 89.53000
# [10/08 11:22:29 nl.defaults.trainer]: Epoch 60 done. Train accuracy: 91.92000, Validation accuracy: 83.65000
# [10/08 11:22:29 nl.defaults.trainer]: Epoch 61 done. Train accuracy: 98.85600, Validation accuracy: 86.15000
# [10/08 11:22:29 nl.defaults.trainer]: Epoch 62 done. Train accuracy: 93.71200, Validation accuracy: 84.33000
# [10/08 11:22:29 nl.defaults.trainer]: Epoch 63 done. Train accuracy: 99.93600, Validation accuracy: 88.08000
# [10/08 11:22:29 nl.defaults.trainer]: Epoch 64 done. Train accuracy: 90.88400, Validation accuracy: 83.71000
# [10/08 11:22:29 nl.defaults.trainer]: Epoch 65 done. Train accuracy: 95.82800, Validation accuracy: 83.78000
# [10/08 11:22:30 nl.defaults.trainer]: Epoch 66 done. Train accuracy: 33.03600, Validation accuracy: 33.92000
# [10/08 11:22:31 nl.defaults.trainer]: Epoch 67 done. Train accuracy: 99.89200, Validation accuracy: 88.53000
# [10/08 11:22:31 nl.defaults.trainer]: Epoch 68 done. Train accuracy: 94.54800, Validation accuracy: 84.56000
# [10/08 11:22:31 nl.defaults.trainer]: Epoch 69 done. Train accuracy: 99.91600, Validation accuracy: 88.76000
# [10/08 11:22:31 nl.defaults.trainer]: Epoch 70 done. Train accuracy: 91.07200, Validation accuracy: 82.95000
# [10/08 11:22:31 nl.defaults.trainer]: Epoch 71 done. Train accuracy: 99.95600, Validation accuracy: 90.11000
# [10/08 11:22:32 nl.defaults.trainer]: Epoch 72 done. Train accuracy: 98.68000, Validation accuracy: 86.54000
# [10/08 11:22:32 nl.defaults.trainer]: Epoch 73 done. Train accuracy: 99.91200, Validation accuracy: 89.09000
# [10/08 11:22:32 nl.defaults.trainer]: Epoch 74 done. Train accuracy: 99.96000, Validation accuracy: 89.08000
# [10/08 11:22:32 nl.defaults.trainer]: Epoch 75 done. Train accuracy: 99.86400, Validation accuracy: 88.78000
# [10/08 11:22:32 nl.defaults.trainer]: Epoch 76 done. Train accuracy: 99.27200, Validation accuracy: 85.33000
# [10/08 11:22:32 nl.defaults.trainer]: Epoch 77 done. Train accuracy: 99.91600, Validation accuracy: 88.67000
# [10/08 11:22:32 nl.defaults.trainer]: Epoch 78 done. Train accuracy: 99.96400, Validation accuracy: 88.87000
# [10/08 11:22:33 nl.defaults.trainer]: Epoch 79 done. Train accuracy: 99.95200, Validation accuracy: 89.62000
# [10/08 11:22:33 nl.defaults.trainer]: Epoch 80 done. Train accuracy: 99.65200, Validation accuracy: 84.09000
# [10/08 11:22:33 nl.defaults.trainer]: Epoch 81 done. Train accuracy: 99.98400, Validation accuracy: 90.83000
# [10/08 11:22:33 nl.defaults.trainer]: Epoch 82 done. Train accuracy: 99.93200, Validation accuracy: 89.25000
# [10/08 11:22:33 nl.defaults.trainer]: Epoch 83 done. Train accuracy: 99.72000, Validation accuracy: 87.88000
# [10/08 11:22:33 nl.defaults.trainer]: Epoch 84 done. Train accuracy: 99.86400, Validation accuracy: 88.18000
# [10/08 11:22:33 nl.defaults.trainer]: Epoch 85 done. Train accuracy: 99.92800, Validation accuracy: 87.67000
# [10/08 11:22:34 nl.defaults.trainer]: Epoch 86 done. Train accuracy: 99.14800, Validation accuracy: 86.85000
# [10/08 11:22:34 nl.defaults.trainer]: Epoch 87 done. Train accuracy: 77.83600, Validation accuracy: 74.21000
# [10/08 11:22:34 nl.defaults.trainer]: Epoch 88 done. Train accuracy: 90.95600, Validation accuracy: 84.16000
# [10/08 11:22:35 nl.defaults.trainer]: Epoch 89 done. Train accuracy: 99.25200, Validation accuracy: 85.30000
# [10/08 11:22:35 nl.defaults.trainer]: Epoch 90 done. Train accuracy: 99.98400, Validation accuracy: 89.78000
# [10/08 11:22:36 nl.defaults.trainer]: Epoch 91 done. Train accuracy: 99.31200, Validation accuracy: 83.35000
# [10/08 11:22:36 nl.defaults.trainer]: Epoch 92 done. Train accuracy: 96.46800, Validation accuracy: 85.50000
# [10/08 11:22:36 nl.defaults.trainer]: Epoch 93 done. Train accuracy: 99.86800, Validation accuracy: 88.34000
# [10/08 11:22:36 nl.defaults.trainer]: Epoch 94 done. Train accuracy: 71.98800, Validation accuracy: 69.32000
# [10/08 11:22:36 nl.defaults.trainer]: Epoch 95 done. Train accuracy: 96.48800, Validation accuracy: 85.80000
# [10/08 11:22:36 nl.defaults.trainer]: Epoch 96 done. Train accuracy: 90.90400, Validation accuracy: 75.80000
# [10/08 11:22:36 nl.defaults.trainer]: Epoch 97 done. Train accuracy: 99.92000, Validation accuracy: 89.50000
# [10/08 11:22:37 nl.defaults.trainer]: Epoch 98 done. Train accuracy: 98.88000, Validation accuracy: 86.40000
# [10/08 11:22:37 nl.defaults.trainer]: Epoch 99 done. Train accuracy: 99.98400, Validation accuracy: 89.97000
# [10/08 11:22:37 nl.defaults.trainer]: Training finished
# Train accuracies: [96.48400001708984, 99.984, 99.964, 99.972, 99.80400000244141, 99.768, 99.96, 99.92, 100.0, 79.53999997558594, 96.30000001708984, 97.95200000732422, 99.936, 99.972, 97.62399997070312, 99.936, 99.88400000488281, 79.52399999023437, 99.984, 99.24400000976563, 99.972, 96.60399998046876, 99.4880000048828, 80.85999997070313, 99.912, 99.684, 99.92800000244141, 81.22399997314453, 98.56000000732422, 81.09999998535156, 82.50399997070312, 99.984, 99.956, 99.62800000244141, 91.44799999267578, 71.94000001953125, 81.19199998291016, 99.8280000024414, 99.8200000024414, 99.896, 99.964, 91.65199998046874, 99.928, 80.97199997070312, 99.46400000244141, 99.928, 99.56, 99.912, 99.98, 99.91600000244141, 99.84, 90.82800001464844, 99.844, 99.908, 99.936, 89.90399999511719, 99.6, 99.272, 90.7760000024414, 99.968, 91.91999999267578, 98.85600000732421, 93.71199997314453, 99.936, 90.88399998291015, 95.82800001464844, 33.036000004882816, 99.892, 94.54799999023437, 99.916, 91.07199998779296, 99.956, 98.68000000976562, 99.912, 99.96, 99.86400000488281, 99.272, 99.91600000244141, 99.964, 99.952, 99.652, 99.984, 99.932, 99.72000000244141, 99.864, 99.928, 99.14800000488282, 77.836, 90.956, 99.25200000732421, 99.984, 99.31200000244141, 96.46800001708985, 99.868, 71.98799999267578, 96.48799997314453, 90.90399997802734, 99.92000000244141, 98.88000000488282, 99.984]
# Validation accuracies: [84.99, 89.59, 89.77, 89.29, 86.0, 88.02, 90.07, 89.08, 91.15, 74.85, 85.59, 85.98, 89.65, 90.32, 85.98, 89.16, 89.64, 74.86, 90.45, 84.74, 90.22, 85.9, 87.33, 71.42, 88.61, 86.31, 88.26, 77.46, 86.44, 71.41, 77.88, 89.97, 88.36, 86.5, 82.42, 66.15, 71.82, 87.97, 85.67, 86.79, 89.26, 83.89, 88.43, 71.87, 86.21, 88.6, 87.4, 87.21, 90.99, 88.84, 88.38, 83.78, 86.73, 88.97, 89.04, 71.76, 87.68, 83.42, 81.19, 89.53, 83.65, 86.15, 84.33, 88.08, 83.71, 83.78, 33.92, 88.53, 84.56, 88.76, 82.95, 90.11, 86.54, 89.09, 89.08, 88.78, 85.33, 88.67, 88.87, 89.62, 84.09, 90.83, 89.25, 87.88, 88.18, 87.67, 86.85, 74.21, 84.16, 85.3, 89.78, 83.35, 85.5, 88.34, 69.32, 85.8, 75.8, 89.5, 86.4, 89.97]
# [10/08 11:22:37 nl.defaults.trainer]: Start evaluation
# [10/08 11:22:37 nl.defaults.trainer]: loading model from file runs/RandomSearch/NasBench201SearchSpace/cifar10/444/search/model_final.pth
# [10/08 11:22:37 nl.defaults.trainer]: Final architecture hash: (2, 2, 0, 0, 3, 2)
# [10/08 11:22:37 nl.defaults.trainer]: Queried results (Metric.VAL_ACCURACY): 91.15
# [10/08 11:22:37 naslib]: Configuration is
# dataset: cifar10
# save: runs/RandomSearch/NasBench201SearchSpace/cifar10/555
# search:
#   checkpoint_freq: 200
#   epochs: 100
#   fidelity: -1
#   population_size: 30
#   sample_size: 10
#   seed: 555
# [10/08 11:22:37 naslib]: Loading Benchmark API
# [10/08 11:22:38 nl.defaults.trainer]: Beginning search
# [10/08 11:22:39 nl.defaults.trainer]: Epoch 0 done. Train accuracy: 97.52400, Validation accuracy: 84.15000
# [10/08 11:22:39 nl.defaults.trainer]: Epoch 1 done. Train accuracy: 99.90400, Validation accuracy: 87.58000
# [10/08 11:22:39 nl.defaults.trainer]: Epoch 2 done. Train accuracy: 99.90800, Validation accuracy: 88.19000
# [10/08 11:22:39 nl.defaults.trainer]: Epoch 3 done. Train accuracy: 99.24800, Validation accuracy: 86.13000
# [10/08 11:22:39 nl.defaults.trainer]: Epoch 4 done. Train accuracy: 98.46400, Validation accuracy: 84.65000
# [10/08 11:22:39 nl.defaults.trainer]: Epoch 5 done. Train accuracy: 91.12800, Validation accuracy: 71.99000
# [10/08 11:22:39 nl.defaults.trainer]: Epoch 6 done. Train accuracy: 89.96400, Validation accuracy: 82.45000
# [10/08 11:22:40 nl.defaults.trainer]: Epoch 7 done. Train accuracy: 99.90800, Validation accuracy: 86.87000
# [10/08 11:22:40 nl.defaults.trainer]: Epoch 8 done. Train accuracy: 97.37600, Validation accuracy: 79.70000
# [10/08 11:22:41 nl.defaults.trainer]: Epoch 9 done. Train accuracy: 91.12800, Validation accuracy: 83.75000
# [10/08 11:22:41 nl.defaults.trainer]: Epoch 10 done. Train accuracy: 99.98000, Validation accuracy: 90.53000
# [10/08 11:22:41 nl.defaults.trainer]: Epoch 11 done. Train accuracy: 81.50400, Validation accuracy: 77.89000
# [10/08 11:22:41 nl.defaults.trainer]: Epoch 12 done. Train accuracy: 99.92400, Validation accuracy: 88.89000
# [10/08 11:22:41 nl.defaults.trainer]: Epoch 13 done. Train accuracy: 90.52400, Validation accuracy: 83.84000
# [10/08 11:22:41 nl.defaults.trainer]: Epoch 14 done. Train accuracy: 99.40000, Validation accuracy: 87.03000
# [10/08 11:22:41 nl.defaults.trainer]: Epoch 15 done. Train accuracy: 99.06400, Validation accuracy: 85.51000
# [10/08 11:22:42 nl.defaults.trainer]: Epoch 16 done. Train accuracy: 99.72800, Validation accuracy: 86.07000
# [10/08 11:22:42 nl.defaults.trainer]: Epoch 17 done. Train accuracy: 99.18000, Validation accuracy: 86.90000
# [10/08 11:22:43 nl.defaults.trainer]: Epoch 18 done. Train accuracy: 70.35600, Validation accuracy: 67.97000
# [10/08 11:22:43 nl.defaults.trainer]: Epoch 19 done. Train accuracy: 90.78800, Validation accuracy: 84.23000
# [10/08 11:22:43 nl.defaults.trainer]: Epoch 20 done. Train accuracy: 88.54000, Validation accuracy: 80.24000
# [10/08 11:22:43 nl.defaults.trainer]: Epoch 21 done. Train accuracy: 99.90800, Validation accuracy: 87.73000
# [10/08 11:22:43 nl.defaults.trainer]: Epoch 22 done. Train accuracy: 99.98000, Validation accuracy: 88.69000
# [10/08 11:22:43 nl.defaults.trainer]: Epoch 23 done. Train accuracy: 99.92800, Validation accuracy: 88.07000
# [10/08 11:22:43 nl.defaults.trainer]: Epoch 24 done. Train accuracy: 99.32400, Validation accuracy: 85.43000
# [10/08 11:22:43 nl.defaults.trainer]: Epoch 25 done. Train accuracy: 94.47600, Validation accuracy: 76.43000
# [10/08 11:22:44 nl.defaults.trainer]: Epoch 26 done. Train accuracy: 90.19600, Validation accuracy: 82.22000
# [10/08 11:22:44 nl.defaults.trainer]: Epoch 27 done. Train accuracy: 99.96800, Validation accuracy: 88.69000
# [10/08 11:22:45 nl.defaults.trainer]: Epoch 28 done. Train accuracy: 99.28800, Validation accuracy: 85.08000
# [10/08 11:22:45 nl.defaults.trainer]: Epoch 29 done. Train accuracy: 99.90400, Validation accuracy: 88.94000
# [10/08 11:22:45 nl.defaults.trainer]: Epoch 30 done. Train accuracy: 93.16000, Validation accuracy: 83.99000
# [10/08 11:22:45 nl.defaults.trainer]: Epoch 31 done. Train accuracy: 99.97200, Validation accuracy: 89.89000
# [10/08 11:22:45 nl.defaults.trainer]: Epoch 32 done. Train accuracy: 99.75200, Validation accuracy: 87.79000
# [10/08 11:22:45 nl.defaults.trainer]: Epoch 33 done. Train accuracy: 99.98800, Validation accuracy: 88.95000
# [10/08 11:22:46 nl.defaults.trainer]: Epoch 34 done. Train accuracy: 99.99200, Validation accuracy: 90.01000
# [10/08 11:22:46 nl.defaults.trainer]: Epoch 35 done. Train accuracy: 99.95600, Validation accuracy: 89.21000
# [10/08 11:22:46 nl.defaults.trainer]: Epoch 36 done. Train accuracy: 99.94000, Validation accuracy: 87.24000
# [10/08 11:22:46 nl.defaults.trainer]: Epoch 37 done. Train accuracy: 99.58000, Validation accuracy: 86.48000
# [10/08 11:22:46 nl.defaults.trainer]: Epoch 38 done. Train accuracy: 99.93600, Validation accuracy: 89.09000
# [10/08 11:22:46 nl.defaults.trainer]: Epoch 39 done. Train accuracy: 99.93600, Validation accuracy: 88.08000
# [10/08 11:22:46 nl.defaults.trainer]: Epoch 40 done. Train accuracy: 98.40800, Validation accuracy: 87.00000
# [10/08 11:22:47 nl.defaults.trainer]: Epoch 41 done. Train accuracy: 99.76400, Validation accuracy: 87.65000
# [10/08 11:22:48 nl.defaults.trainer]: Epoch 42 done. Train accuracy: 99.89600, Validation accuracy: 87.51000
# [10/08 11:22:48 nl.defaults.trainer]: Epoch 43 done. Train accuracy: 96.25600, Validation accuracy: 85.72000
# [10/08 11:22:48 nl.defaults.trainer]: Epoch 44 done. Train accuracy: 99.93600, Validation accuracy: 88.58000
# [10/08 11:22:48 nl.defaults.trainer]: Epoch 45 done. Train accuracy: 99.95600, Validation accuracy: 88.71000
# [10/08 11:22:48 nl.defaults.trainer]: Epoch 46 done. Train accuracy: 91.44800, Validation accuracy: 82.42000
# [10/08 11:22:48 nl.defaults.trainer]: Epoch 47 done. Train accuracy: 86.15600, Validation accuracy: 81.96000
# [10/08 11:22:48 nl.defaults.trainer]: Epoch 48 done. Train accuracy: 99.45200, Validation accuracy: 85.13000
# [10/08 11:22:49 nl.defaults.trainer]: Epoch 49 done. Train accuracy: 99.91600, Validation accuracy: 89.73000
# [10/08 11:22:49 nl.defaults.trainer]: Epoch 50 done. Train accuracy: 99.99200, Validation accuracy: 90.96000
# [10/08 11:22:49 nl.defaults.trainer]: Epoch 51 done. Train accuracy: 81.30400, Validation accuracy: 71.97000
# [10/08 11:22:49 nl.defaults.trainer]: Epoch 52 done. Train accuracy: 99.58000, Validation accuracy: 86.83000
# [10/08 11:22:49 nl.defaults.trainer]: Epoch 53 done. Train accuracy: 99.92400, Validation accuracy: 87.26000
# [10/08 11:22:49 nl.defaults.trainer]: Epoch 54 done. Train accuracy: 97.26000, Validation accuracy: 85.61000
# [10/08 11:22:50 nl.defaults.trainer]: Epoch 55 done. Train accuracy: 80.66000, Validation accuracy: 77.02000
# [10/08 11:22:50 nl.defaults.trainer]: Epoch 56 done. Train accuracy: 100.00000, Validation accuracy: 90.82000
# [10/08 11:22:51 nl.defaults.trainer]: Epoch 57 done. Train accuracy: 99.98000, Validation accuracy: 88.99000
# [10/08 11:22:51 nl.defaults.trainer]: Epoch 58 done. Train accuracy: 99.95200, Validation accuracy: 89.49000
# [10/08 11:22:51 nl.defaults.trainer]: Epoch 59 done. Train accuracy: 71.14000, Validation accuracy: 68.50000
# [10/08 11:22:51 nl.defaults.trainer]: Epoch 60 done. Train accuracy: 99.51200, Validation accuracy: 87.69000
# [10/08 11:22:51 nl.defaults.trainer]: Epoch 61 done. Train accuracy: 90.88000, Validation accuracy: 83.64000
# [10/08 11:22:52 nl.defaults.trainer]: Epoch 62 done. Train accuracy: 99.96000, Validation accuracy: 89.36000
# [10/08 11:22:52 nl.defaults.trainer]: Epoch 63 done. Train accuracy: 99.64400, Validation accuracy: 87.46000
# [10/08 11:22:52 nl.defaults.trainer]: Epoch 64 done. Train accuracy: 92.02400, Validation accuracy: 82.41000
# [10/08 11:22:52 nl.defaults.trainer]: Epoch 65 done. Train accuracy: 60.70800, Validation accuracy: 60.01000
# [10/08 11:22:52 nl.defaults.trainer]: Epoch 66 done. Train accuracy: 93.99200, Validation accuracy: 85.14000
# [10/08 11:22:52 nl.defaults.trainer]: Epoch 67 done. Train accuracy: 99.64800, Validation accuracy: 86.59000
# [10/08 11:22:52 nl.defaults.trainer]: Epoch 68 done. Train accuracy: 95.46400, Validation accuracy: 82.66000
# [10/08 11:22:53 nl.defaults.trainer]: Epoch 69 done. Train accuracy: 99.93600, Validation accuracy: 89.14000
# [10/08 11:22:53 nl.defaults.trainer]: Epoch 70 done. Train accuracy: 99.91600, Validation accuracy: 88.33000
# [10/08 11:22:53 nl.defaults.trainer]: Epoch 71 done. Train accuracy: 99.91200, Validation accuracy: 88.71000
# [10/08 11:22:53 nl.defaults.trainer]: Epoch 72 done. Train accuracy: 99.82800, Validation accuracy: 88.34000
# [10/08 11:22:53 nl.defaults.trainer]: Epoch 73 done. Train accuracy: 99.93200, Validation accuracy: 88.64000
# [10/08 11:22:53 nl.defaults.trainer]: Epoch 74 done. Train accuracy: 99.94000, Validation accuracy: 87.34000
# [10/08 11:22:53 nl.defaults.trainer]: Epoch 75 done. Train accuracy: 99.21200, Validation accuracy: 86.35000
# [10/08 11:22:54 nl.defaults.trainer]: Epoch 76 done. Train accuracy: 99.26400, Validation accuracy: 86.77000
# [10/08 11:22:55 nl.defaults.trainer]: Epoch 77 done. Train accuracy: 99.95600, Validation accuracy: 88.28000
# [10/08 11:22:55 nl.defaults.trainer]: Epoch 78 done. Train accuracy: 99.98000, Validation accuracy: 88.71000
# [10/08 11:22:55 nl.defaults.trainer]: Epoch 79 done. Train accuracy: 96.63200, Validation accuracy: 86.02000
# [10/08 11:22:55 nl.defaults.trainer]: Epoch 80 done. Train accuracy: 97.18400, Validation accuracy: 85.36000
# [10/08 11:22:55 nl.defaults.trainer]: Epoch 81 done. Train accuracy: 99.63200, Validation accuracy: 87.87000
# [10/08 11:22:56 nl.defaults.trainer]: Epoch 82 done. Train accuracy: 98.81200, Validation accuracy: 85.59000
# [10/08 11:22:56 nl.defaults.trainer]: Epoch 83 done. Train accuracy: 99.92800, Validation accuracy: 87.39000
# [10/08 11:22:56 nl.defaults.trainer]: Epoch 84 done. Train accuracy: 80.11600, Validation accuracy: 76.33000
# [10/08 11:22:56 nl.defaults.trainer]: Epoch 85 done. Train accuracy: 99.92000, Validation accuracy: 88.42000
# [10/08 11:22:56 nl.defaults.trainer]: Epoch 86 done. Train accuracy: 96.39200, Validation accuracy: 86.00000
# [10/08 11:22:56 nl.defaults.trainer]: Epoch 87 done. Train accuracy: 90.55600, Validation accuracy: 83.58000
# [10/08 11:22:56 nl.defaults.trainer]: Epoch 88 done. Train accuracy: 99.34000, Validation accuracy: 86.66000
# [10/08 11:22:57 nl.defaults.trainer]: Epoch 89 done. Train accuracy: 97.58400, Validation accuracy: 79.64000
# [10/08 11:22:57 nl.defaults.trainer]: Epoch 90 done. Train accuracy: 99.84800, Validation accuracy: 86.82000
# [10/08 11:22:57 nl.defaults.trainer]: Epoch 91 done. Train accuracy: 99.98800, Validation accuracy: 89.50000
# [10/08 11:22:57 nl.defaults.trainer]: Epoch 92 done. Train accuracy: 80.92800, Validation accuracy: 70.90000
# [10/08 11:22:57 nl.defaults.trainer]: Epoch 93 done. Train accuracy: 81.62800, Validation accuracy: 71.24000
# [10/08 11:22:57 nl.defaults.trainer]: Epoch 94 done. Train accuracy: 76.02000, Validation accuracy: 72.17000
# [10/08 11:22:57 nl.defaults.trainer]: Epoch 95 done. Train accuracy: 99.94400, Validation accuracy: 89.01000
# [10/08 11:22:58 nl.defaults.trainer]: Epoch 96 done. Train accuracy: 99.93200, Validation accuracy: 88.28000
# [10/08 11:22:58 nl.defaults.trainer]: Epoch 97 done. Train accuracy: 97.95200, Validation accuracy: 85.98000
# [10/08 11:22:58 nl.defaults.trainer]: Epoch 98 done. Train accuracy: 80.34800, Validation accuracy: 70.72000
# [10/08 11:22:58 nl.defaults.trainer]: Epoch 99 done. Train accuracy: 99.62000, Validation accuracy: 87.25000
# [10/08 11:22:58 nl.defaults.trainer]: Training finished
# Train accuracies: [97.52400001464844, 99.904, 99.908, 99.2480000024414, 98.4640000048828, 91.12800000488281, 89.96399998535156, 99.908, 97.37600000976562, 91.12799998535156, 99.98, 81.50399998046875, 99.9240000024414, 90.5239999951172, 99.40000000488281, 99.0640000024414, 99.728, 99.18, 70.35599998779297, 90.78799998779297, 88.53999999511718, 99.90800000244141, 99.98, 99.928, 99.32400000732422, 94.47599997558594, 90.19599999755859, 99.968, 99.28800000732421, 99.904, 93.15999998535156, 99.972, 99.752, 99.988, 99.992, 99.956, 99.94, 99.58000000488282, 99.936, 99.936, 98.40800001220703, 99.764, 99.896, 96.25600001953126, 99.936, 99.956, 91.44799999267578, 86.15600000732422, 99.45200000244141, 99.916, 99.992, 81.30399997558594, 99.58, 99.924, 97.26000001464844, 80.65999997314454, 100.0, 99.98, 99.952, 71.13999997802735, 99.51200000732422, 90.87999998779297, 99.96, 99.6440000024414, 92.02399998779296, 60.70799998413086, 93.99199997314453, 99.6480000024414, 95.46400001464843, 99.936, 99.916, 99.912, 99.8280000024414, 99.932, 99.94, 99.212, 99.26400000488282, 99.956, 99.98, 96.63200001464844, 97.18399997070313, 99.632, 98.81200000244141, 99.928, 80.11599997070313, 99.92, 96.39200001220703, 90.55599998779297, 99.3400000024414, 97.58400000732422, 99.848, 99.988, 80.92799998046875, 81.62799998291015, 76.02000000488282, 99.944, 99.932, 97.95200000732422, 80.34799998291015, 99.62]
# Validation accuracies: [84.15, 87.58, 88.19, 86.13, 84.65, 71.99, 82.45, 86.87, 79.7, 83.75, 90.53, 77.89, 88.89, 83.84, 87.03, 85.51, 86.07, 86.9, 67.97, 84.23, 80.24, 87.73, 88.69, 88.07, 85.43, 76.43, 82.22, 88.69, 85.08, 88.94, 83.99, 89.89, 87.79, 88.95, 90.01, 89.21, 87.24, 86.48, 89.09, 88.08, 87.0, 87.65, 87.51, 85.72, 88.58, 88.71, 82.42, 81.96, 85.13, 89.73, 90.96, 71.97, 86.83, 87.26, 85.61, 77.02, 90.82, 88.99, 89.49, 68.5, 87.69, 83.64, 89.36, 87.46, 82.41, 60.01, 85.14, 86.59, 82.66, 89.14, 88.33, 88.71, 88.34, 88.64, 87.34, 86.35, 86.77, 88.28, 88.71, 86.02, 85.36, 87.87, 85.59, 87.39, 76.33, 88.42, 86.0, 83.58, 86.66, 79.64, 86.82, 89.5, 70.9, 71.24, 72.17, 89.01, 88.28, 85.98, 70.72, 87.25]
# [10/08 11:22:58 nl.defaults.trainer]: Start evaluation
# [10/08 11:22:58 nl.defaults.trainer]: loading model from file runs/RandomSearch/NasBench201SearchSpace/cifar10/555/search/model_final.pth
# [10/08 11:22:58 nl.defaults.trainer]: Final architecture hash: (1, 2, 0, 0, 4, 2)
# [10/08 11:22:58 nl.defaults.trainer]: Queried results (Metric.VAL_ACCURACY): 90.96

# %%
# Plot RS for three seeds
plot_optimizers(trajectories_rs,"NAS-Bench-201 cifar10")

# %% [markdown]
# ### TASK 2: Search using the Regularized Evolution Optimizer
# 1. Search using the Regularized Evolution Optimizer for 100 epochs
# 2. Use NASBench301 search space with cifar10 dataset
# 2. Plot the search trajectories of RE for cifar10

# %% [markdown]
# ## Regularized Evolution
# ![](https://drive.google.com/uc?id=11rF0ZQSoth4dMe8G5tmdemw2WBmXBerF)

# %%
trajectories_re= {}

# %%
# TODO:
# 1. Use the Regularized Evolution optimizer instead of RandomSearch 
# 2. Use the NASBench301SearchSpace for cifar100 
# 3. Plot the RE search trajectory for NASBench301 and cifar10

# Set the optimizer type
optimizer_type = ...
# Set the search space type
search_space_type = ...

# Set the dataset
dataset = ... 

# The configuration used by the Trainer and Optimizer
# The missing information will be populated inside run_optimizer
config = {
    'search': {
        # Required by Trainer
        'epochs': 100,
        'checkpoint_freq': 100,
        
        # Required by Random Search optimizer
        'fidelity': -1,
        
        # Required by RegularizedEvolution
        'sample_size': 10,
        'population_size': 30,
    }
}
config = CfgNode.load_cfg(json.dumps(config))
#Initialize trajectories for the 3 seeds
trajectories_re["RE"] = []
for seed in [333,444,555]: #Run RS for 3 seeds
  search_trajectory, best_model, best_model_val_acc = run_optimizer(
                                                        optimizer_type,
                                                        search_space_type,
                                                        dataset,
                                                        config,
                                                        seed
                                                    )
  trajectories_re["RE"].append(search_trajectory)

# %%
# Plot RS and RE for three seeds
plot_optimizers(trajectories_re,"NAS-Bench-301 cifar10")

# %% [markdown]
# ### BANANAS
# ![](https://drive.google.com/uc?id=1KelEs9KUXpyO1MiO_jJ4b7gQSMWgJBlz)

# %%
#initialize the trajectory for BANANAS
trajectories_bn={}

# %%
# Now lets use BANANAS as a search optimizer with xgb as predictor
# Note: We are fitting a predictor preriodicaly so this is expected to be slower than RE and RS
from naslib.search_spaces.core.query_metrics import Metric
from naslib import utils
from naslib.utils import get_dataset_api
from naslib.utils.logging import setup_logger
import os
import logging
import sys
from naslib.defaults.trainer import Trainer


from fvcore.common.config import CfgNode
optimizer_type = Bananas # {RegularizedEvolution, RandomSearch}
search_space_type = NasBench201SearchSpace # {NasBench101SearchSpace, NasBench201SearchSpace, NasBench301SearchSpace}

# Set the dataset
dataset = 'cifar10' # cifar10 for NB101 and NB301, {cifar100, ImageNet16-120} for NB201

#define the predictor
predictor = 'xgb' 
for seed in [333,444,555]:
  config = {
    'search': {
        # Required by Trainer
        'epochs': 100,
        'checkpoint_freq': 100,
        
        # Required by Random Search optimizer
        'fidelity': -1,
        'k':20,
        "num_init":10,
        "num_ensemble":1,
        # Required by RegularizedEvolution
        'sample_size': 10,
        'population_size': 30,
        "predictor_type": predictor,
        "acq_fn_type": "its",
        "acq_fn_optimization": 'random_sampling',
        "encoding_type": 'path',
        "num_arches_to_mutate":5,
        "max_mutations":1,
        "num_candidates":100
     }
   }
  config = CfgNode.load_cfg(json.dumps(config))

  search_trajectory, best_model, best_model_val_acc = run_optimizer(
                                                        optimizer_type,
                                                        search_space_type,
                                                        dataset,
                                                        config,
                                                        seed
                                                    )
  if "BANANAS_"+str(predictor) in trajectories_bn.keys():
    trajectories_bn["BANANAS_"+str(predictor)].append(search_trajectory)
  else: 
    trajectories_bn["BANANAS_"+str(predictor)] = []
    trajectories_bn["BANANAS_"+str(predictor)].append(search_trajectory)
# Out:
# [10/08 11:51:20 naslib]: Configuration is
# dataset: cifar10
# save: runs/Bananas/NasBench201SearchSpace/cifar10/333
# search:
#   acq_fn_optimization: random_sampling
#   acq_fn_type: its
#   checkpoint_freq: 100
#   encoding_type: path
#   epochs: 100
#   fidelity: -1
#   k: 20
#   max_mutations: 1
#   num_arches_to_mutate: 5
#   num_candidates: 100
#   num_ensemble: 1
#   num_init: 10
#   population_size: 30
#   predictor_type: xgb
#   sample_size: 10
#   seed: 333
# [10/08 11:51:20 naslib]: Loading Benchmark API
# [10/08 11:51:21 nl.defaults.trainer]: Beginning search
# [10/08 11:51:21 nl.defaults.trainer]: Epoch 0 done. Train accuracy: 99.54800, Validation accuracy: 83.83000
# [10/08 11:51:21 nl.defaults.trainer]: Epoch 1 done. Train accuracy: 72.61200, Validation accuracy: 66.22000
# [10/08 11:51:21 nl.defaults.trainer]: Epoch 2 done. Train accuracy: 99.91200, Validation accuracy: 88.09000
# [10/08 11:51:22 nl.defaults.trainer]: Epoch 3 done. Train accuracy: 99.88400, Validation accuracy: 88.68000
# [10/08 11:51:22 nl.defaults.trainer]: Epoch 4 done. Train accuracy: 99.92000, Validation accuracy: 89.14000
# [10/08 11:51:22 nl.defaults.trainer]: Epoch 5 done. Train accuracy: 99.98800, Validation accuracy: 90.01000
# [10/08 11:51:22 nl.defaults.trainer]: Epoch 6 done. Train accuracy: 97.94400, Validation accuracy: 85.91000
# [10/08 11:51:23 nl.defaults.trainer]: Epoch 7 done. Train accuracy: 89.03200, Validation accuracy: 81.87000
# [10/08 11:51:23 nl.defaults.trainer]: Epoch 8 done. Train accuracy: 72.39200, Validation accuracy: 66.30000
# [10/08 11:51:23 nl.defaults.trainer]: Epoch 9 done. Train accuracy: 99.52800, Validation accuracy: 87.35000
# [10/08 11:51:45 nl.defaults.trainer]: Epoch 10 done. Train accuracy: 99.97200, Validation accuracy: 90.10000
# [10/08 11:51:45 nl.defaults.trainer]: Epoch 11 done. Train accuracy: 99.98800, Validation accuracy: 90.56000
# [10/08 11:51:45 nl.defaults.trainer]: Epoch 12 done. Train accuracy: 99.98400, Validation accuracy: 90.95000
# [10/08 11:51:45 nl.defaults.trainer]: Epoch 13 done. Train accuracy: 99.95200, Validation accuracy: 88.68000
# [10/08 11:51:45 nl.defaults.trainer]: Epoch 14 done. Train accuracy: 99.94400, Validation accuracy: 89.93000
# [10/08 11:51:45 nl.defaults.trainer]: Epoch 15 done. Train accuracy: 99.92000, Validation accuracy: 89.51000
# [10/08 11:51:45 nl.defaults.trainer]: Epoch 16 done. Train accuracy: 99.96400, Validation accuracy: 88.33000
# [10/08 11:51:45 nl.defaults.trainer]: Epoch 17 done. Train accuracy: 99.88800, Validation accuracy: 88.93000
# [10/08 11:51:45 nl.defaults.trainer]: Epoch 18 done. Train accuracy: 99.90400, Validation accuracy: 86.58000
# [10/08 11:51:45 nl.defaults.trainer]: Epoch 19 done. Train accuracy: 90.96800, Validation accuracy: 84.01000
# [10/08 11:51:45 nl.defaults.trainer]: Epoch 20 done. Train accuracy: 99.95600, Validation accuracy: 88.94000
# [10/08 11:51:45 nl.defaults.trainer]: Epoch 21 done. Train accuracy: 91.50400, Validation accuracy: 82.99000
# [10/08 11:51:45 nl.defaults.trainer]: Epoch 22 done. Train accuracy: 99.96400, Validation accuracy: 88.91000
# [10/08 11:51:45 nl.defaults.trainer]: Epoch 23 done. Train accuracy: 99.75200, Validation accuracy: 87.90000
# [10/08 11:51:45 nl.defaults.trainer]: Epoch 24 done. Train accuracy: 98.34400, Validation accuracy: 84.97000
# [10/08 11:51:45 nl.defaults.trainer]: Epoch 25 done. Train accuracy: 75.50000, Validation accuracy: 72.65000
# [10/08 11:51:45 nl.defaults.trainer]: Epoch 26 done. Train accuracy: 99.98800, Validation accuracy: 90.33000
# [10/08 11:51:45 nl.defaults.trainer]: Epoch 27 done. Train accuracy: 99.95600, Validation accuracy: 90.20000
# [10/08 11:51:45 nl.defaults.trainer]: Epoch 28 done. Train accuracy: 91.22000, Validation accuracy: 84.73000
# [10/08 11:51:45 nl.defaults.trainer]: Epoch 29 done. Train accuracy: 98.07200, Validation accuracy: 84.94000
# [10/08 11:52:07 nl.defaults.trainer]: Epoch 30 done. Train accuracy: 99.98000, Validation accuracy: 90.38000
# [10/08 11:52:07 nl.defaults.trainer]: Epoch 31 done. Train accuracy: 99.99600, Validation accuracy: 90.66000
# [10/08 11:52:07 nl.defaults.trainer]: Epoch 32 done. Train accuracy: 99.60400, Validation accuracy: 87.60000
# [10/08 11:52:07 nl.defaults.trainer]: Epoch 33 done. Train accuracy: 99.94000, Validation accuracy: 88.77000
# [10/08 11:52:07 nl.defaults.trainer]: Epoch 34 done. Train accuracy: 99.93200, Validation accuracy: 88.94000
# [10/08 11:52:07 nl.defaults.trainer]: Epoch 35 done. Train accuracy: 98.83200, Validation accuracy: 86.67000
# [10/08 11:52:07 nl.defaults.trainer]: Epoch 36 done. Train accuracy: 99.30000, Validation accuracy: 87.15000
# [10/08 11:52:07 nl.defaults.trainer]: Epoch 37 done. Train accuracy: 98.46000, Validation accuracy: 85.48000
# [10/08 11:52:07 nl.defaults.trainer]: Epoch 38 done. Train accuracy: 96.00000, Validation accuracy: 85.33000
# [10/08 11:52:07 nl.defaults.trainer]: Epoch 39 done. Train accuracy: 99.96400, Validation accuracy: 89.21000
# [10/08 11:52:07 nl.defaults.trainer]: Epoch 40 done. Train accuracy: 99.92400, Validation accuracy: 88.85000
# [10/08 11:52:07 nl.defaults.trainer]: Epoch 41 done. Train accuracy: 99.39200, Validation accuracy: 87.00000
# [10/08 11:52:07 nl.defaults.trainer]: Epoch 42 done. Train accuracy: 99.97600, Validation accuracy: 90.23000
# [10/08 11:52:07 nl.defaults.trainer]: Epoch 43 done. Train accuracy: 99.90800, Validation accuracy: 87.80000
# [10/08 11:52:07 nl.defaults.trainer]: Epoch 44 done. Train accuracy: 99.91600, Validation accuracy: 88.55000
# [10/08 11:52:07 nl.defaults.trainer]: Epoch 45 done. Train accuracy: 99.84400, Validation accuracy: 88.28000
# [10/08 11:52:07 nl.defaults.trainer]: Epoch 46 done. Train accuracy: 99.92000, Validation accuracy: 88.67000
# [10/08 11:52:07 nl.defaults.trainer]: Epoch 47 done. Train accuracy: 99.83200, Validation accuracy: 88.10000
# [10/08 11:52:07 nl.defaults.trainer]: Epoch 48 done. Train accuracy: 99.98400, Validation accuracy: 89.48000
# [10/08 11:52:07 nl.defaults.trainer]: Epoch 49 done. Train accuracy: 99.94800, Validation accuracy: 89.49000
# [10/08 11:52:29 nl.defaults.trainer]: Epoch 50 done. Train accuracy: 99.19200, Validation accuracy: 86.46000
# [10/08 11:52:29 nl.defaults.trainer]: Epoch 51 done. Train accuracy: 99.98800, Validation accuracy: 90.56000
# [10/08 11:52:29 nl.defaults.trainer]: Epoch 52 done. Train accuracy: 99.84000, Validation accuracy: 88.29000
# [10/08 11:52:29 nl.defaults.trainer]: Epoch 53 done. Train accuracy: 99.95200, Validation accuracy: 89.68000
# [10/08 11:52:29 nl.defaults.trainer]: Epoch 54 done. Train accuracy: 99.98000, Validation accuracy: 88.75000
# [10/08 11:52:29 nl.defaults.trainer]: Epoch 55 done. Train accuracy: 99.49200, Validation accuracy: 86.63000
# [10/08 11:52:29 nl.defaults.trainer]: Epoch 56 done. Train accuracy: 99.92800, Validation accuracy: 89.22000
# [10/08 11:52:29 nl.defaults.trainer]: Epoch 57 done. Train accuracy: 99.92800, Validation accuracy: 88.08000
# [10/08 11:52:29 nl.defaults.trainer]: Epoch 58 done. Train accuracy: 98.33200, Validation accuracy: 86.62000
# [10/08 11:52:29 nl.defaults.trainer]: Epoch 59 done. Train accuracy: 99.97200, Validation accuracy: 89.00000
# [10/08 11:52:29 nl.defaults.trainer]: Epoch 60 done. Train accuracy: 99.98000, Validation accuracy: 88.65000
# [10/08 11:52:29 nl.defaults.trainer]: Epoch 61 done. Train accuracy: 99.94400, Validation accuracy: 88.57000
# [10/08 11:52:29 nl.defaults.trainer]: Epoch 62 done. Train accuracy: 99.93200, Validation accuracy: 89.30000
# [10/08 11:52:29 nl.defaults.trainer]: Epoch 63 done. Train accuracy: 99.96800, Validation accuracy: 89.64000
# [10/08 11:52:29 nl.defaults.trainer]: Epoch 64 done. Train accuracy: 99.97200, Validation accuracy: 88.00000
# [10/08 11:52:29 nl.defaults.trainer]: Epoch 65 done. Train accuracy: 99.94400, Validation accuracy: 88.83000
# [10/08 11:52:29 nl.defaults.trainer]: Epoch 66 done. Train accuracy: 99.92800, Validation accuracy: 88.35000
# [10/08 11:52:29 nl.defaults.trainer]: Epoch 67 done. Train accuracy: 99.91600, Validation accuracy: 88.72000
# [10/08 11:52:29 nl.defaults.trainer]: Epoch 68 done. Train accuracy: 99.74800, Validation accuracy: 87.86000
# [10/08 11:52:29 nl.defaults.trainer]: Epoch 69 done. Train accuracy: 99.96400, Validation accuracy: 88.05000
# [10/08 11:52:50 nl.defaults.trainer]: Epoch 70 done. Train accuracy: 99.97200, Validation accuracy: 89.37000
# [10/08 11:52:50 nl.defaults.trainer]: Epoch 71 done. Train accuracy: 99.97200, Validation accuracy: 89.43000
# [10/08 11:52:50 nl.defaults.trainer]: Epoch 72 done. Train accuracy: 99.98000, Validation accuracy: 89.08000
# [10/08 11:52:50 nl.defaults.trainer]: Epoch 73 done. Train accuracy: 99.96400, Validation accuracy: 88.18000
# [10/08 11:52:50 nl.defaults.trainer]: Epoch 74 done. Train accuracy: 99.98000, Validation accuracy: 89.06000
# [10/08 11:52:50 nl.defaults.trainer]: Epoch 75 done. Train accuracy: 99.94400, Validation accuracy: 89.45000
# [10/08 11:52:50 nl.defaults.trainer]: Epoch 76 done. Train accuracy: 99.89200, Validation accuracy: 87.31000
# [10/08 11:52:50 nl.defaults.trainer]: Epoch 77 done. Train accuracy: 99.96800, Validation accuracy: 89.30000
# [10/08 11:52:50 nl.defaults.trainer]: Epoch 78 done. Train accuracy: 99.91200, Validation accuracy: 88.83000
# [10/08 11:52:50 nl.defaults.trainer]: Epoch 79 done. Train accuracy: 99.96800, Validation accuracy: 89.55000
# [10/08 11:52:50 nl.defaults.trainer]: Epoch 80 done. Train accuracy: 99.95600, Validation accuracy: 89.33000
# [10/08 11:52:50 nl.defaults.trainer]: Epoch 81 done. Train accuracy: 99.98400, Validation accuracy: 89.46000
# [10/08 11:52:50 nl.defaults.trainer]: Epoch 82 done. Train accuracy: 99.96000, Validation accuracy: 89.00000
# [10/08 11:52:50 nl.defaults.trainer]: Epoch 83 done. Train accuracy: 99.93200, Validation accuracy: 88.71000
# [10/08 11:52:50 nl.defaults.trainer]: Epoch 84 done. Train accuracy: 99.97600, Validation accuracy: 89.62000
# [10/08 11:52:50 nl.defaults.trainer]: Epoch 85 done. Train accuracy: 99.96800, Validation accuracy: 89.50000
# [10/08 11:52:50 nl.defaults.trainer]: Epoch 86 done. Train accuracy: 99.98000, Validation accuracy: 88.65000
# [10/08 11:52:50 nl.defaults.trainer]: Epoch 87 done. Train accuracy: 99.91200, Validation accuracy: 89.61000
# [10/08 11:52:50 nl.defaults.trainer]: Epoch 88 done. Train accuracy: 99.86800, Validation accuracy: 87.77000
# [10/08 11:52:50 nl.defaults.trainer]: Epoch 89 done. Train accuracy: 99.52000, Validation accuracy: 87.23000
# [10/08 11:53:13 nl.defaults.trainer]: Epoch 90 done. Train accuracy: 99.98800, Validation accuracy: 90.33000
# [10/08 11:53:13 nl.defaults.trainer]: Epoch 91 done. Train accuracy: 86.70400, Validation accuracy: 82.09000
# [10/08 11:53:13 nl.defaults.trainer]: Epoch 92 done. Train accuracy: 99.96000, Validation accuracy: 89.56000
# [10/08 11:53:13 nl.defaults.trainer]: Epoch 93 done. Train accuracy: 99.95600, Validation accuracy: 89.43000
# [10/08 11:53:13 nl.defaults.trainer]: Epoch 94 done. Train accuracy: 99.91600, Validation accuracy: 88.45000
# [10/08 11:53:13 nl.defaults.trainer]: Epoch 95 done. Train accuracy: 99.94800, Validation accuracy: 89.05000
# [10/08 11:53:13 nl.defaults.trainer]: Epoch 96 done. Train accuracy: 99.99200, Validation accuracy: 90.24000
# [10/08 11:53:13 nl.defaults.trainer]: Epoch 97 done. Train accuracy: 78.73200, Validation accuracy: 73.95000
# [10/08 11:53:13 nl.defaults.trainer]: Epoch 98 done. Train accuracy: 99.98000, Validation accuracy: 88.85000
# [10/08 11:53:13 nl.defaults.trainer]: Epoch 99 done. Train accuracy: 99.76800, Validation accuracy: 88.02000
# [10/08 11:53:13 nl.defaults.trainer]: Training finished
# Train accuracies: [99.548, 72.61199998291016, 99.912, 99.88400000244141, 99.92, 99.988, 97.94400000732422, 89.03200001220704, 72.39200001953125, 99.528, 99.972, 99.988, 99.984, 99.952, 99.944, 99.92, 99.964, 99.888, 99.904, 90.96799999023438, 99.956, 91.50399999023438, 99.964, 99.75200000488282, 98.34400000732421, 75.50000000976563, 99.988, 99.956, 91.21999999511719, 98.07200000976563, 99.98, 99.996, 99.6040000048828, 99.94, 99.932, 98.8320000024414, 99.30000000244141, 98.46000000976562, 96.00000001953126, 99.964, 99.924, 99.3920000024414, 99.976, 99.908, 99.916, 99.8440000024414, 99.92, 99.832, 99.984, 99.948, 99.192, 99.988, 99.84, 99.952, 99.98, 99.4920000024414, 99.928, 99.928, 98.33200000488281, 99.972, 99.98, 99.944, 99.932, 99.968, 99.972, 99.944, 99.928, 99.916, 99.748, 99.964, 99.972, 99.972, 99.98, 99.964, 99.98, 99.944, 99.892, 99.968, 99.912, 99.968, 99.956, 99.984, 99.96, 99.932, 99.976, 99.968, 99.98, 99.912, 99.868, 99.52, 99.988, 86.70399997802734, 99.96, 99.956, 99.916, 99.948, 99.992, 78.73199999023437, 99.98, 99.768]
# Validation accuracies: [83.83, 66.22, 88.09, 88.68, 89.14, 90.01, 85.91, 81.87, 66.3, 87.35, 90.1, 90.56, 90.95, 88.68, 89.93, 89.51, 88.33, 88.93, 86.58, 84.01, 88.94, 82.99, 88.91, 87.9, 84.97, 72.65, 90.33, 90.2, 84.73, 84.94, 90.38, 90.66, 87.6, 88.77, 88.94, 86.67, 87.15, 85.48, 85.33, 89.21, 88.85, 87.0, 90.23, 87.8, 88.55, 88.28, 88.67, 88.1, 89.48, 89.49, 86.46, 90.56, 88.29, 89.68, 88.75, 86.63, 89.22, 88.08, 86.62, 89.0, 88.65, 88.57, 89.3, 89.64, 88.0, 88.83, 88.35, 88.72, 87.86, 88.05, 89.37, 89.43, 89.08, 88.18, 89.06, 89.45, 87.31, 89.3, 88.83, 89.55, 89.33, 89.46, 89.0, 88.71, 89.62, 89.5, 88.65, 89.61, 87.77, 87.23, 90.33, 82.09, 89.56, 89.43, 88.45, 89.05, 90.24, 73.95, 88.85, 88.02]
# [10/08 11:53:13 nl.defaults.trainer]: Start evaluation
# [10/08 11:53:13 nl.defaults.trainer]: loading model from file runs/Bananas/NasBench201SearchSpace/cifar10/333/search/model_final.pth
# [10/08 11:53:13 nl.defaults.trainer]: Final architecture hash: (3, 2, 0, 0, 3, 2)
# [10/08 11:53:13 nl.defaults.trainer]: Queried results (Metric.VAL_ACCURACY): 90.95
# [10/08 11:53:14 naslib]: Configuration is
# dataset: cifar10
# save: runs/Bananas/NasBench201SearchSpace/cifar10/444
# search:
#   acq_fn_optimization: random_sampling
#   acq_fn_type: its
#   checkpoint_freq: 100
#   encoding_type: path
#   epochs: 100
#   fidelity: -1
#   k: 20
#   max_mutations: 1
#   num_arches_to_mutate: 5
#   num_candidates: 100
#   num_ensemble: 1
#   num_init: 10
#   population_size: 30
#   predictor_type: xgb
#   sample_size: 10
#   seed: 444
# [10/08 11:53:14 naslib]: Loading Benchmark API
# [10/08 11:53:15 nl.defaults.trainer]: Beginning search
# [10/08 11:53:16 nl.defaults.trainer]: Epoch 0 done. Train accuracy: 96.48400, Validation accuracy: 84.99000
# [10/08 11:53:16 nl.defaults.trainer]: Epoch 1 done. Train accuracy: 99.98400, Validation accuracy: 89.59000
# [10/08 11:53:16 nl.defaults.trainer]: Epoch 2 done. Train accuracy: 99.96400, Validation accuracy: 89.77000
# [10/08 11:53:16 nl.defaults.trainer]: Epoch 3 done. Train accuracy: 99.97200, Validation accuracy: 89.29000
# [10/08 11:53:17 nl.defaults.trainer]: Epoch 4 done. Train accuracy: 99.80400, Validation accuracy: 86.00000
# [10/08 11:53:17 nl.defaults.trainer]: Epoch 5 done. Train accuracy: 99.76800, Validation accuracy: 88.02000
# [10/08 11:53:17 nl.defaults.trainer]: Epoch 6 done. Train accuracy: 99.96000, Validation accuracy: 90.07000
# [10/08 11:53:18 nl.defaults.trainer]: Epoch 7 done. Train accuracy: 99.92000, Validation accuracy: 89.08000
# [10/08 11:53:18 nl.defaults.trainer]: Epoch 8 done. Train accuracy: 100.00000, Validation accuracy: 91.15000
# [10/08 11:53:18 nl.defaults.trainer]: Epoch 9 done. Train accuracy: 79.54000, Validation accuracy: 74.85000
# [10/08 11:53:40 nl.defaults.trainer]: Epoch 10 done. Train accuracy: 99.98400, Validation accuracy: 89.78000
# [10/08 11:53:40 nl.defaults.trainer]: Epoch 11 done. Train accuracy: 99.82000, Validation accuracy: 85.67000
# [10/08 11:53:40 nl.defaults.trainer]: Epoch 12 done. Train accuracy: 99.98400, Validation accuracy: 90.45000
# [10/08 11:53:40 nl.defaults.trainer]: Epoch 13 done. Train accuracy: 99.96800, Validation accuracy: 90.21000
# [10/08 11:53:40 nl.defaults.trainer]: Epoch 14 done. Train accuracy: 99.97200, Validation accuracy: 90.32000
# [10/08 11:53:40 nl.defaults.trainer]: Epoch 15 done. Train accuracy: 99.86800, Validation accuracy: 88.34000
# [10/08 11:53:40 nl.defaults.trainer]: Epoch 16 done. Train accuracy: 99.93600, Validation accuracy: 89.16000
# [10/08 11:53:40 nl.defaults.trainer]: Epoch 17 done. Train accuracy: 99.97200, Validation accuracy: 90.22000
# [10/08 11:53:40 nl.defaults.trainer]: Epoch 18 done. Train accuracy: 99.88400, Validation accuracy: 89.64000
# [10/08 11:53:40 nl.defaults.trainer]: Epoch 19 done. Train accuracy: 91.44800, Validation accuracy: 82.42000
# [10/08 11:53:40 nl.defaults.trainer]: Epoch 20 done. Train accuracy: 98.88000, Validation accuracy: 86.40000
# [10/08 11:53:40 nl.defaults.trainer]: Epoch 21 done. Train accuracy: 80.97200, Validation accuracy: 71.87000
# [10/08 11:53:40 nl.defaults.trainer]: Epoch 22 done. Train accuracy: 90.77600, Validation accuracy: 81.19000
# [10/08 11:53:40 nl.defaults.trainer]: Epoch 23 done. Train accuracy: 97.95200, Validation accuracy: 85.98000
# [10/08 11:53:40 nl.defaults.trainer]: Epoch 24 done. Train accuracy: 98.85600, Validation accuracy: 86.15000
# [10/08 11:53:40 nl.defaults.trainer]: Epoch 25 done. Train accuracy: 99.27200, Validation accuracy: 85.33000
# [10/08 11:53:40 nl.defaults.trainer]: Epoch 26 done. Train accuracy: 99.91200, Validation accuracy: 89.09000
# [10/08 11:53:40 nl.defaults.trainer]: Epoch 27 done. Train accuracy: 99.81600, Validation accuracy: 87.45000
# [10/08 11:53:40 nl.defaults.trainer]: Epoch 28 done. Train accuracy: 99.48800, Validation accuracy: 87.33000
# [10/08 11:53:41 nl.defaults.trainer]: Epoch 29 done. Train accuracy: 99.14800, Validation accuracy: 86.85000
# [10/08 11:54:01 nl.defaults.trainer]: Epoch 30 done. Train accuracy: 99.96000, Validation accuracy: 89.96000
# [10/08 11:54:01 nl.defaults.trainer]: Epoch 31 done. Train accuracy: 99.96000, Validation accuracy: 87.39000
# [10/08 11:54:01 nl.defaults.trainer]: Epoch 32 done. Train accuracy: 99.94000, Validation accuracy: 87.70000
# [10/08 11:54:01 nl.defaults.trainer]: Epoch 33 done. Train accuracy: 99.91600, Validation accuracy: 88.01000
# [10/08 11:54:01 nl.defaults.trainer]: Epoch 34 done. Train accuracy: 99.94400, Validation accuracy: 88.90000
# [10/08 11:54:01 nl.defaults.trainer]: Epoch 35 done. Train accuracy: 99.79200, Validation accuracy: 87.42000
# [10/08 11:54:01 nl.defaults.trainer]: Epoch 36 done. Train accuracy: 99.98000, Validation accuracy: 90.46000
# [10/08 11:54:01 nl.defaults.trainer]: Epoch 37 done. Train accuracy: 99.85600, Validation accuracy: 88.64000
# [10/08 11:54:01 nl.defaults.trainer]: Epoch 38 done. Train accuracy: 100.00000, Validation accuracy: 91.18000
# [10/08 11:54:01 nl.defaults.trainer]: Epoch 39 done. Train accuracy: 99.34800, Validation accuracy: 84.49000
# [10/08 11:54:01 nl.defaults.trainer]: Epoch 40 done. Train accuracy: 99.99200, Validation accuracy: 90.08000
# [10/08 11:54:01 nl.defaults.trainer]: Epoch 41 done. Train accuracy: 96.65200, Validation accuracy: 84.93000
# [10/08 11:54:01 nl.defaults.trainer]: Epoch 42 done. Train accuracy: 10.28800, Validation accuracy: 10.00000
# [10/08 11:54:01 nl.defaults.trainer]: Epoch 43 done. Train accuracy: 99.96400, Validation accuracy: 89.09000
# [10/08 11:54:01 nl.defaults.trainer]: Epoch 44 done. Train accuracy: 99.90000, Validation accuracy: 88.49000
# [10/08 11:54:01 nl.defaults.trainer]: Epoch 45 done. Train accuracy: 99.96000, Validation accuracy: 88.74000
# [10/08 11:54:01 nl.defaults.trainer]: Epoch 46 done. Train accuracy: 99.98400, Validation accuracy: 90.14000
# [10/08 11:54:01 nl.defaults.trainer]: Epoch 47 done. Train accuracy: 99.64800, Validation accuracy: 85.01000
# [10/08 11:54:01 nl.defaults.trainer]: Epoch 48 done. Train accuracy: 99.86800, Validation accuracy: 88.48000
# [10/08 11:54:01 nl.defaults.trainer]: Epoch 49 done. Train accuracy: 99.86000, Validation accuracy: 82.25000
# [10/08 11:54:23 nl.defaults.trainer]: Epoch 50 done. Train accuracy: 99.96400, Validation accuracy: 90.07000
# [10/08 11:54:23 nl.defaults.trainer]: Epoch 51 done. Train accuracy: 99.99600, Validation accuracy: 89.43000
# [10/08 11:54:23 nl.defaults.trainer]: Epoch 52 done. Train accuracy: 96.41200, Validation accuracy: 85.53000
# [10/08 11:54:23 nl.defaults.trainer]: Epoch 53 done. Train accuracy: 99.90000, Validation accuracy: 88.65000
# [10/08 11:54:23 nl.defaults.trainer]: Epoch 54 done. Train accuracy: 98.94800, Validation accuracy: 85.72000
# [10/08 11:54:23 nl.defaults.trainer]: Epoch 55 done. Train accuracy: 99.91600, Validation accuracy: 88.76000
# [10/08 11:54:23 nl.defaults.trainer]: Epoch 56 done. Train accuracy: 99.98800, Validation accuracy: 89.23000
# [10/08 11:54:23 nl.defaults.trainer]: Epoch 57 done. Train accuracy: 99.96000, Validation accuracy: 88.64000
# [10/08 11:54:23 nl.defaults.trainer]: Epoch 58 done. Train accuracy: 99.97200, Validation accuracy: 88.00000
# [10/08 11:54:23 nl.defaults.trainer]: Epoch 59 done. Train accuracy: 99.97200, Validation accuracy: 88.34000
# [10/08 11:54:23 nl.defaults.trainer]: Epoch 60 done. Train accuracy: 99.93600, Validation accuracy: 88.72000
# [10/08 11:54:23 nl.defaults.trainer]: Epoch 61 done. Train accuracy: 99.96800, Validation accuracy: 89.95000
# [10/08 11:54:23 nl.defaults.trainer]: Epoch 62 done. Train accuracy: 99.96000, Validation accuracy: 89.20000
# [10/08 11:54:23 nl.defaults.trainer]: Epoch 63 done. Train accuracy: 99.94000, Validation accuracy: 86.50000
# [10/08 11:54:23 nl.defaults.trainer]: Epoch 64 done. Train accuracy: 99.94800, Validation accuracy: 88.00000
# [10/08 11:54:23 nl.defaults.trainer]: Epoch 65 done. Train accuracy: 99.94800, Validation accuracy: 87.67000
# [10/08 11:54:23 nl.defaults.trainer]: Epoch 66 done. Train accuracy: 99.98800, Validation accuracy: 88.73000
# [10/08 11:54:23 nl.defaults.trainer]: Epoch 67 done. Train accuracy: 99.96800, Validation accuracy: 88.48000
# [10/08 11:54:23 nl.defaults.trainer]: Epoch 68 done. Train accuracy: 99.97600, Validation accuracy: 89.95000
# [10/08 11:54:23 nl.defaults.trainer]: Epoch 69 done. Train accuracy: 99.84800, Validation accuracy: 87.11000
# [10/08 11:54:43 nl.defaults.trainer]: Epoch 70 done. Train accuracy: 99.98800, Validation accuracy: 90.67000
# [10/08 11:54:43 nl.defaults.trainer]: Epoch 71 done. Train accuracy: 99.97600, Validation accuracy: 90.13000
# [10/08 11:54:43 nl.defaults.trainer]: Epoch 72 done. Train accuracy: 99.72800, Validation accuracy: 88.23000
# [10/08 11:54:43 nl.defaults.trainer]: Epoch 73 done. Train accuracy: 80.66000, Validation accuracy: 71.37000
# [10/08 11:54:43 nl.defaults.trainer]: Epoch 74 done. Train accuracy: 99.98400, Validation accuracy: 89.47000
# [10/08 11:54:43 nl.defaults.trainer]: Epoch 75 done. Train accuracy: 99.94000, Validation accuracy: 89.00000
# [10/08 11:54:43 nl.defaults.trainer]: Epoch 76 done. Train accuracy: 97.25200, Validation accuracy: 85.73000
# [10/08 11:54:43 nl.defaults.trainer]: Epoch 77 done. Train accuracy: 99.91600, Validation accuracy: 88.69000
# [10/08 11:54:43 nl.defaults.trainer]: Epoch 78 done. Train accuracy: 99.73600, Validation accuracy: 87.74000
# [10/08 11:54:43 nl.defaults.trainer]: Epoch 79 done. Train accuracy: 99.92800, Validation accuracy: 88.91000
# [10/08 11:54:43 nl.defaults.trainer]: Epoch 80 done. Train accuracy: 99.50800, Validation accuracy: 87.54000
# [10/08 11:54:43 nl.defaults.trainer]: Epoch 81 done. Train accuracy: 100.00000, Validation accuracy: 90.63000
# [10/08 11:54:43 nl.defaults.trainer]: Epoch 82 done. Train accuracy: 99.97200, Validation accuracy: 90.13000
# [10/08 11:54:43 nl.defaults.trainer]: Epoch 83 done. Train accuracy: 99.98000, Validation accuracy: 90.55000
# [10/08 11:54:43 nl.defaults.trainer]: Epoch 84 done. Train accuracy: 99.97600, Validation accuracy: 88.63000
# [10/08 11:54:43 nl.defaults.trainer]: Epoch 85 done. Train accuracy: 98.96000, Validation accuracy: 83.06000
# [10/08 11:54:43 nl.defaults.trainer]: Epoch 86 done. Train accuracy: 99.92000, Validation accuracy: 88.69000
# [10/08 11:54:43 nl.defaults.trainer]: Epoch 87 done. Train accuracy: 99.93600, Validation accuracy: 86.98000
# [10/08 11:54:43 nl.defaults.trainer]: Epoch 88 done. Train accuracy: 99.94800, Validation accuracy: 88.76000
# [10/08 11:54:43 nl.defaults.trainer]: Epoch 89 done. Train accuracy: 99.96000, Validation accuracy: 88.62000
# [10/08 11:55:08 nl.defaults.trainer]: Epoch 90 done. Train accuracy: 99.98400, Validation accuracy: 90.75000
# [10/08 11:55:08 nl.defaults.trainer]: Epoch 91 done. Train accuracy: 99.97600, Validation accuracy: 89.76000
# [10/08 11:55:08 nl.defaults.trainer]: Epoch 92 done. Train accuracy: 99.95600, Validation accuracy: 89.26000
# [10/08 11:55:08 nl.defaults.trainer]: Epoch 93 done. Train accuracy: 99.92400, Validation accuracy: 88.62000
# [10/08 11:55:08 nl.defaults.trainer]: Epoch 94 done. Train accuracy: 99.97200, Validation accuracy: 89.90000
# [10/08 11:55:08 nl.defaults.trainer]: Epoch 95 done. Train accuracy: 99.96800, Validation accuracy: 89.22000
# [10/08 11:55:08 nl.defaults.trainer]: Epoch 96 done. Train accuracy: 91.42000, Validation accuracy: 84.02000
# [10/08 11:55:08 nl.defaults.trainer]: Epoch 97 done. Train accuracy: 99.93600, Validation accuracy: 89.51000
# [10/08 11:55:08 nl.defaults.trainer]: Epoch 98 done. Train accuracy: 99.93600, Validation accuracy: 88.08000
# [10/08 11:55:08 nl.defaults.trainer]: Epoch 99 done. Train accuracy: 99.82800, Validation accuracy: 86.56000
# [10/08 11:55:08 nl.defaults.trainer]: Training finished
# Train accuracies: [96.48400001708984, 99.984, 99.964, 99.972, 99.80400000244141, 99.768, 99.96, 99.92, 100.0, 79.53999997558594, 99.984, 99.8200000024414, 99.984, 99.968, 99.972, 99.868, 99.936, 99.972, 99.88400000488281, 91.44799999267578, 98.88000000488282, 80.97199997070312, 90.7760000024414, 97.95200000732422, 98.85600000732421, 99.272, 99.912, 99.816, 99.4880000048828, 99.14800000488282, 99.96, 99.96, 99.94, 99.916, 99.944, 99.792, 99.98, 99.856, 100.0, 99.34800000244141, 99.992, 96.65200001953124, 10.287999999389648, 99.964, 99.9, 99.96, 99.984, 99.648, 99.868, 99.8600000048828, 99.964, 99.996, 96.41200001708984, 99.9, 98.94800000488281, 99.916, 99.988, 99.96, 99.972, 99.972, 99.936, 99.968, 99.96, 99.94, 99.948, 99.948, 99.988, 99.968, 99.976, 99.848, 99.988, 99.976, 99.728, 80.65999997558593, 99.984, 99.94, 97.25200001220703, 99.916, 99.7360000024414, 99.928, 99.508, 100.0, 99.972, 99.98, 99.976, 98.96000000488282, 99.92000000244141, 99.936, 99.948, 99.96, 99.984, 99.976, 99.956, 99.924, 99.972, 99.968, 91.41999999267578, 99.936, 99.936, 99.8280000024414]
# Validation accuracies: [84.99, 89.59, 89.77, 89.29, 86.0, 88.02, 90.07, 89.08, 91.15, 74.85, 89.78, 85.67, 90.45, 90.21, 90.32, 88.34, 89.16, 90.22, 89.64, 82.42, 86.4, 71.87, 81.19, 85.98, 86.15, 85.33, 89.09, 87.45, 87.33, 86.85, 89.96, 87.39, 87.7, 88.01, 88.9, 87.42, 90.46, 88.64, 91.18, 84.49, 90.08, 84.93, 10.0, 89.09, 88.49, 88.74, 90.14, 85.01, 88.48, 82.25, 90.07, 89.43, 85.53, 88.65, 85.72, 88.76, 89.23, 88.64, 88.0, 88.34, 88.72, 89.95, 89.2, 86.5, 88.0, 87.67, 88.73, 88.48, 89.95, 87.11, 90.67, 90.13, 88.23, 71.37, 89.47, 89.0, 85.73, 88.69, 87.74, 88.91, 87.54, 90.63, 90.13, 90.55, 88.63, 83.06, 88.69, 86.98, 88.76, 88.62, 90.75, 89.76, 89.26, 88.62, 89.9, 89.22, 84.02, 89.51, 88.08, 86.56]
# [10/08 11:55:08 nl.defaults.trainer]: Start evaluation
# [10/08 11:55:08 nl.defaults.trainer]: loading model from file runs/Bananas/NasBench201SearchSpace/cifar10/444/search/model_final.pth
# [10/08 11:55:08 nl.defaults.trainer]: Final architecture hash: (2, 2, 0, 2, 2, 3)
# [10/08 11:55:08 nl.defaults.trainer]: Queried results (Metric.VAL_ACCURACY): 91.18
# [10/08 11:55:09 naslib]: Configuration is
# dataset: cifar10
# save: runs/Bananas/NasBench201SearchSpace/cifar10/555
# search:
#   acq_fn_optimization: random_sampling
#   acq_fn_type: its
#   checkpoint_freq: 100
#   encoding_type: path
#   epochs: 100
#   fidelity: -1
#   k: 20
#   max_mutations: 1
#   num_arches_to_mutate: 5
#   num_candidates: 100
#   num_ensemble: 1
#   num_init: 10
#   population_size: 30
#   predictor_type: xgb
#   sample_size: 10
#   seed: 555
# [10/08 11:55:09 naslib]: Loading Benchmark API
# [10/08 11:55:10 nl.defaults.trainer]: Beginning search
# [10/08 11:55:11 nl.defaults.trainer]: Epoch 0 done. Train accuracy: 97.52400, Validation accuracy: 84.15000
# [10/08 11:55:11 nl.defaults.trainer]: Epoch 1 done. Train accuracy: 99.90400, Validation accuracy: 87.58000
# [10/08 11:55:11 nl.defaults.trainer]: Epoch 2 done. Train accuracy: 99.90800, Validation accuracy: 88.19000
# [10/08 11:55:11 nl.defaults.trainer]: Epoch 3 done. Train accuracy: 99.24800, Validation accuracy: 86.13000
# [10/08 11:55:11 nl.defaults.trainer]: Epoch 4 done. Train accuracy: 98.46400, Validation accuracy: 84.65000
# [10/08 11:55:11 nl.defaults.trainer]: Epoch 5 done. Train accuracy: 91.12800, Validation accuracy: 71.99000
# [10/08 11:55:11 nl.defaults.trainer]: Epoch 6 done. Train accuracy: 89.96400, Validation accuracy: 82.45000
# [10/08 11:55:12 nl.defaults.trainer]: Epoch 7 done. Train accuracy: 99.90800, Validation accuracy: 86.87000
# [10/08 11:55:12 nl.defaults.trainer]: Epoch 8 done. Train accuracy: 97.37600, Validation accuracy: 79.70000
# [10/08 11:55:12 nl.defaults.trainer]: Epoch 9 done. Train accuracy: 91.12800, Validation accuracy: 83.75000
# [10/08 11:55:37 nl.defaults.trainer]: Epoch 10 done. Train accuracy: 99.95600, Validation accuracy: 88.28000
# [10/08 11:55:37 nl.defaults.trainer]: Epoch 11 done. Train accuracy: 99.64800, Validation accuracy: 86.59000
# [10/08 11:55:37 nl.defaults.trainer]: Epoch 12 done. Train accuracy: 99.94000, Validation accuracy: 87.34000
# [10/08 11:55:37 nl.defaults.trainer]: Epoch 13 done. Train accuracy: 99.82800, Validation accuracy: 88.34000
# [10/08 11:55:37 nl.defaults.trainer]: Epoch 14 done. Train accuracy: 99.28800, Validation accuracy: 85.08000
# [10/08 11:55:37 nl.defaults.trainer]: Epoch 15 done. Train accuracy: 98.11200, Validation accuracy: 82.75000
# [10/08 11:55:37 nl.defaults.trainer]: Epoch 16 done. Train accuracy: 76.02000, Validation accuracy: 72.17000
# [10/08 11:55:37 nl.defaults.trainer]: Epoch 17 done. Train accuracy: 80.66000, Validation accuracy: 77.02000
# [10/08 11:55:37 nl.defaults.trainer]: Epoch 18 done. Train accuracy: 70.35600, Validation accuracy: 67.97000
# [10/08 11:55:37 nl.defaults.trainer]: Epoch 19 done. Train accuracy: 99.92400, Validation accuracy: 88.89000
# [10/08 11:55:37 nl.defaults.trainer]: Epoch 20 done. Train accuracy: 99.95600, Validation accuracy: 89.21000
# [10/08 11:55:37 nl.defaults.trainer]: Epoch 21 done. Train accuracy: 99.98000, Validation accuracy: 90.53000
# [10/08 11:55:37 nl.defaults.trainer]: Epoch 22 done. Train accuracy: 99.95600, Validation accuracy: 88.71000
# [10/08 11:55:37 nl.defaults.trainer]: Epoch 23 done. Train accuracy: 99.93600, Validation accuracy: 88.08000
# [10/08 11:55:37 nl.defaults.trainer]: Epoch 24 done. Train accuracy: 99.96800, Validation accuracy: 89.78000
# [10/08 11:55:37 nl.defaults.trainer]: Epoch 25 done. Train accuracy: 90.78800, Validation accuracy: 84.23000
# [10/08 11:55:37 nl.defaults.trainer]: Epoch 26 done. Train accuracy: 99.06400, Validation accuracy: 85.51000
# [10/08 11:55:37 nl.defaults.trainer]: Epoch 27 done. Train accuracy: 99.91600, Validation accuracy: 89.73000
# [10/08 11:55:37 nl.defaults.trainer]: Epoch 28 done. Train accuracy: 99.98800, Validation accuracy: 88.95000
# [10/08 11:55:37 nl.defaults.trainer]: Epoch 29 done. Train accuracy: 99.76400, Validation accuracy: 87.65000
# [10/08 11:55:58 nl.defaults.trainer]: Epoch 30 done. Train accuracy: 99.91600, Validation accuracy: 88.98000
# [10/08 11:55:59 nl.defaults.trainer]: Epoch 31 done. Train accuracy: 99.98800, Validation accuracy: 90.73000
# [10/08 11:55:59 nl.defaults.trainer]: Epoch 32 done. Train accuracy: 99.99200, Validation accuracy: 90.45000
# [10/08 11:55:59 nl.defaults.trainer]: Epoch 33 done. Train accuracy: 99.94400, Validation accuracy: 88.88000
# [10/08 11:55:59 nl.defaults.trainer]: Epoch 34 done. Train accuracy: 99.96400, Validation accuracy: 88.91000
# [10/08 11:55:59 nl.defaults.trainer]: Epoch 35 done. Train accuracy: 99.84800, Validation accuracy: 88.22000
# [10/08 11:55:59 nl.defaults.trainer]: Epoch 36 done. Train accuracy: 99.93200, Validation accuracy: 88.89000
# [10/08 11:55:59 nl.defaults.trainer]: Epoch 37 done. Train accuracy: 99.97600, Validation accuracy: 88.83000
# [10/08 11:55:59 nl.defaults.trainer]: Epoch 38 done. Train accuracy: 99.96000, Validation accuracy: 89.29000
# [10/08 11:55:59 nl.defaults.trainer]: Epoch 39 done. Train accuracy: 99.96800, Validation accuracy: 89.10000
# [10/08 11:55:59 nl.defaults.trainer]: Epoch 40 done. Train accuracy: 99.95200, Validation accuracy: 88.38000
# [10/08 11:55:59 nl.defaults.trainer]: Epoch 41 done. Train accuracy: 99.98800, Validation accuracy: 89.97000
# [10/08 11:55:59 nl.defaults.trainer]: Epoch 42 done. Train accuracy: 93.56000, Validation accuracy: 79.23000
# [10/08 11:55:59 nl.defaults.trainer]: Epoch 43 done. Train accuracy: 99.95600, Validation accuracy: 89.04000
# [10/08 11:55:59 nl.defaults.trainer]: Epoch 44 done. Train accuracy: 99.95200, Validation accuracy: 88.43000
# [10/08 11:55:59 nl.defaults.trainer]: Epoch 45 done. Train accuracy: 99.91600, Validation accuracy: 87.94000
# [10/08 11:55:59 nl.defaults.trainer]: Epoch 46 done. Train accuracy: 99.88000, Validation accuracy: 88.67000
# [10/08 11:55:59 nl.defaults.trainer]: Epoch 47 done. Train accuracy: 99.91600, Validation accuracy: 88.83000
# [10/08 11:55:59 nl.defaults.trainer]: Epoch 48 done. Train accuracy: 99.02800, Validation accuracy: 86.12000
# [10/08 11:55:59 nl.defaults.trainer]: Epoch 49 done. Train accuracy: 99.94400, Validation accuracy: 88.74000
# [10/08 11:56:19 nl.defaults.trainer]: Epoch 50 done. Train accuracy: 99.95600, Validation accuracy: 89.46000
# [10/08 11:56:19 nl.defaults.trainer]: Epoch 51 done. Train accuracy: 99.98000, Validation accuracy: 90.46000
# [10/08 11:56:19 nl.defaults.trainer]: Epoch 52 done. Train accuracy: 99.97600, Validation accuracy: 89.80000
# [10/08 11:56:19 nl.defaults.trainer]: Epoch 53 done. Train accuracy: 99.97600, Validation accuracy: 89.78000
# [10/08 11:56:19 nl.defaults.trainer]: Epoch 54 done. Train accuracy: 99.94800, Validation accuracy: 89.45000
# [10/08 11:56:19 nl.defaults.trainer]: Epoch 55 done. Train accuracy: 99.98400, Validation accuracy: 90.64000
# [10/08 11:56:19 nl.defaults.trainer]: Epoch 56 done. Train accuracy: 99.96800, Validation accuracy: 89.36000
# [10/08 11:56:19 nl.defaults.trainer]: Epoch 57 done. Train accuracy: 99.96400, Validation accuracy: 89.66000
# [10/08 11:56:19 nl.defaults.trainer]: Epoch 58 done. Train accuracy: 99.95200, Validation accuracy: 89.06000
# [10/08 11:56:19 nl.defaults.trainer]: Epoch 59 done. Train accuracy: 99.96400, Validation accuracy: 89.54000
# [10/08 11:56:19 nl.defaults.trainer]: Epoch 60 done. Train accuracy: 99.97600, Validation accuracy: 89.52000
# [10/08 11:56:19 nl.defaults.trainer]: Epoch 61 done. Train accuracy: 99.91200, Validation accuracy: 88.32000
# [10/08 11:56:19 nl.defaults.trainer]: Epoch 62 done. Train accuracy: 94.21600, Validation accuracy: 83.70000
# [10/08 11:56:19 nl.defaults.trainer]: Epoch 63 done. Train accuracy: 99.55200, Validation accuracy: 86.80000
# [10/08 11:56:19 nl.defaults.trainer]: Epoch 64 done. Train accuracy: 98.99600, Validation accuracy: 86.33000
# [10/08 11:56:19 nl.defaults.trainer]: Epoch 65 done. Train accuracy: 99.55600, Validation accuracy: 87.42000
# [10/08 11:56:19 nl.defaults.trainer]: Epoch 66 done. Train accuracy: 99.90400, Validation accuracy: 86.83000
# [10/08 11:56:19 nl.defaults.trainer]: Epoch 67 done. Train accuracy: 99.94000, Validation accuracy: 88.43000
# [10/08 11:56:19 nl.defaults.trainer]: Epoch 68 done. Train accuracy: 99.99200, Validation accuracy: 90.78000
# [10/08 11:56:19 nl.defaults.trainer]: Epoch 69 done. Train accuracy: 99.78800, Validation accuracy: 88.36000
# [10/08 11:56:39 nl.defaults.trainer]: Epoch 70 done. Train accuracy: 99.98800, Validation accuracy: 90.51000
# [10/08 11:56:39 nl.defaults.trainer]: Epoch 71 done. Train accuracy: 99.98400, Validation accuracy: 90.87000
# [10/08 11:56:39 nl.defaults.trainer]: Epoch 72 done. Train accuracy: 99.96000, Validation accuracy: 89.58000
# [10/08 11:56:39 nl.defaults.trainer]: Epoch 73 done. Train accuracy: 99.95600, Validation accuracy: 89.65000
# [10/08 11:56:39 nl.defaults.trainer]: Epoch 74 done. Train accuracy: 99.97600, Validation accuracy: 90.28000
# [10/08 11:56:39 nl.defaults.trainer]: Epoch 75 done. Train accuracy: 99.94800, Validation accuracy: 89.12000
# [10/08 11:56:39 nl.defaults.trainer]: Epoch 76 done. Train accuracy: 99.96400, Validation accuracy: 88.93000
# [10/08 11:56:39 nl.defaults.trainer]: Epoch 77 done. Train accuracy: 74.78800, Validation accuracy: 71.93000
# [10/08 11:56:39 nl.defaults.trainer]: Epoch 78 done. Train accuracy: 99.29600, Validation accuracy: 87.20000
# [10/08 11:56:39 nl.defaults.trainer]: Epoch 79 done. Train accuracy: 99.97600, Validation accuracy: 90.48000
# [10/08 11:56:39 nl.defaults.trainer]: Epoch 80 done. Train accuracy: 99.60000, Validation accuracy: 87.52000
# [10/08 11:56:39 nl.defaults.trainer]: Epoch 81 done. Train accuracy: 99.96400, Validation accuracy: 88.26000
# [10/08 11:56:39 nl.defaults.trainer]: Epoch 82 done. Train accuracy: 99.91200, Validation accuracy: 88.14000
# [10/08 11:56:39 nl.defaults.trainer]: Epoch 83 done. Train accuracy: 99.94400, Validation accuracy: 88.88000
# [10/08 11:56:39 nl.defaults.trainer]: Epoch 84 done. Train accuracy: 99.92800, Validation accuracy: 88.63000
# [10/08 11:56:39 nl.defaults.trainer]: Epoch 85 done. Train accuracy: 91.70400, Validation accuracy: 82.60000
# [10/08 11:56:39 nl.defaults.trainer]: Epoch 86 done. Train accuracy: 99.93600, Validation accuracy: 88.43000
# [10/08 11:56:39 nl.defaults.trainer]: Epoch 87 done. Train accuracy: 99.96000, Validation accuracy: 88.17000
# [10/08 11:56:39 nl.defaults.trainer]: Epoch 88 done. Train accuracy: 99.86800, Validation accuracy: 88.34000
# [10/08 11:56:39 nl.defaults.trainer]: Epoch 89 done. Train accuracy: 99.86800, Validation accuracy: 88.34000
# [10/08 11:56:59 nl.defaults.trainer]: Epoch 90 done. Train accuracy: 99.98400, Validation accuracy: 90.83000
# [10/08 11:56:59 nl.defaults.trainer]: Epoch 91 done. Train accuracy: 99.98000, Validation accuracy: 89.67000
# [10/08 11:56:59 nl.defaults.trainer]: Epoch 92 done. Train accuracy: 99.92000, Validation accuracy: 88.59000
# [10/08 11:56:59 nl.defaults.trainer]: Epoch 93 done. Train accuracy: 99.95600, Validation accuracy: 89.58000
# [10/08 11:56:59 nl.defaults.trainer]: Epoch 94 done. Train accuracy: 99.95600, Validation accuracy: 89.11000
# [10/08 11:56:59 nl.defaults.trainer]: Epoch 95 done. Train accuracy: 99.83200, Validation accuracy: 88.59000
# [10/08 11:56:59 nl.defaults.trainer]: Epoch 96 done. Train accuracy: 99.96800, Validation accuracy: 89.83000
# [10/08 11:56:59 nl.defaults.trainer]: Epoch 97 done. Train accuracy: 99.94000, Validation accuracy: 89.00000
# [10/08 11:56:59 nl.defaults.trainer]: Epoch 98 done. Train accuracy: 99.89600, Validation accuracy: 88.98000
# [10/08 11:56:59 nl.defaults.trainer]: Epoch 99 done. Train accuracy: 99.96400, Validation accuracy: 89.16000
# [10/08 11:56:59 nl.defaults.trainer]: Training finished
# Train accuracies: [97.52400001464844, 99.904, 99.908, 99.2480000024414, 98.4640000048828, 91.12800000488281, 89.96399998535156, 99.908, 97.37600000976562, 91.12799998535156, 99.956, 99.6480000024414, 99.94, 99.8280000024414, 99.28800000732421, 98.11200001220703, 76.02000000488282, 80.65999997314454, 70.35599998779297, 99.9240000024414, 99.956, 99.98, 99.956, 99.936, 99.968, 90.78799998779297, 99.0640000024414, 99.916, 99.988, 99.764, 99.916, 99.988, 99.992, 99.944, 99.964, 99.848, 99.93200000244141, 99.976, 99.96, 99.968, 99.952, 99.988, 93.55999997314453, 99.956, 99.952, 99.916, 99.88, 99.916, 99.0280000024414, 99.944, 99.9560000024414, 99.98, 99.976, 99.976, 99.948, 99.984, 99.9680000024414, 99.964, 99.952, 99.964, 99.976, 99.912, 94.21600001953125, 99.55200000732422, 98.99600001220703, 99.55600000488282, 99.904, 99.94, 99.992, 99.788, 99.988, 99.984, 99.96, 99.956, 99.976, 99.948, 99.964, 74.78799998046875, 99.29600000976562, 99.976, 99.60000000488282, 99.964, 99.912, 99.944, 99.928, 91.70399998046875, 99.936, 99.96, 99.868, 99.868, 99.984, 99.98, 99.92, 99.956, 99.956, 99.8320000024414, 99.968, 99.94, 99.896, 99.96400000244141]
# Validation accuracies: [84.15, 87.58, 88.19, 86.13, 84.65, 71.99, 82.45, 86.87, 79.7, 83.75, 88.28, 86.59, 87.34, 88.34, 85.08, 82.75, 72.17, 77.02, 67.97, 88.89, 89.21, 90.53, 88.71, 88.08, 89.78, 84.23, 85.51, 89.73, 88.95, 87.65, 88.98, 90.73, 90.45, 88.88, 88.91, 88.22, 88.89, 88.83, 89.29, 89.1, 88.38, 89.97, 79.23, 89.04, 88.43, 87.94, 88.67, 88.83, 86.12, 88.74, 89.46, 90.46, 89.8, 89.78, 89.45, 90.64, 89.36, 89.66, 89.06, 89.54, 89.52, 88.32, 83.7, 86.8, 86.33, 87.42, 86.83, 88.43, 90.78, 88.36, 90.51, 90.87, 89.58, 89.65, 90.28, 89.12, 88.93, 71.93, 87.2, 90.48, 87.52, 88.26, 88.14, 88.88, 88.63, 82.6, 88.43, 88.17, 88.34, 88.34, 90.83, 89.67, 88.59, 89.58, 89.11, 88.59, 89.83, 89.0, 88.98, 89.16]
# [10/08 11:56:59 nl.defaults.trainer]: Start evaluation
# [10/08 11:56:59 nl.defaults.trainer]: loading model from file runs/Bananas/NasBench201SearchSpace/cifar10/555/search/model_final.pth
# [10/08 11:56:59 nl.defaults.trainer]: Final architecture hash: (2, 3, 0, 2, 4, 3)
# [10/08 11:56:59 nl.defaults.trainer]: Queried results (Metric.VAL_ACCURACY): 90.87

# %%
# Plot Bananas (xgb predictor), RS and RE
plot_optimizers(trajectories_bn,"NAS-Bench-201 cifar10")

# %% [markdown]
# ### TASK 3: BANANAS with predictor of your choice
# 1. Choose any predictor from amongst `'mlp','lgb', 'rf','bayes_lin_reg','gp'` and run search using BANANAS
# 2. Use NASBench201 search space for the ImageNet16-120 dataset
# 3. Plot your results

# %%
trajectories_bn_imgnet={}

# %%
# Bananas with any other predictor of your choice
from naslib.search_spaces.core.query_metrics import Metric
from naslib import utils
from naslib.utils import get_dataset_api
from naslib.utils.logging import setup_logger
import os
import logging
import sys
from naslib.defaults.trainer import Trainer
from naslib.optimizers import (
    DARTSOptimizer,
    GDASOptimizer,
    DrNASOptimizer,
    RandomSearch,
    RegularizedEvolution,
    LocalSearch,
    Bananas,
    BasePredictor,
)
import json
from naslib.search_spaces import (
    NasBench301SearchSpace,
    SimpleCellSearchSpace,
    NasBench201SearchSpace,
    HierarchicalSearchSpace,
)

from fvcore.common.config import CfgNode
optimizer_type = Bananas # {RegularizedEvolution, RandomSearch}
search_space_type = ... # Specify the search space

# Set the dataset
dataset = ... # Specify the dataset

predictor = ... # Specify the predictor
for seed in [333,444,555]:
  config = {
    'search': {
        # Required by Trainer
        'epochs': 100,
        'checkpoint_freq': 100,
        
        # Required by Random Search optimizer
        'fidelity': -1,
        'k':20,
        "num_init":10,
        "num_ensemble":1,
        # Required by RegularizedEvolution
        'sample_size': 10,
        'population_size': 30,
        "predictor_type": predictor,
        "acq_fn_type": "its",
        "acq_fn_optimization": 'random_sampling',
        "encoding_type": 'path',
        "num_arches_to_mutate":5,
        "max_mutations":1,
        "num_candidates":100
     }
   }
  config = CfgNode.load_cfg(json.dumps(config))

  search_trajectory, best_model, best_model_val_acc = run_optimizer(
                                                        optimizer_type,
                                                        search_space_type,
                                                        dataset,
                                                        '',
                                                        config,
                                                        seed
                                                    )
  if predictor in trajectories_bn_imgnet.keys():
    trajectories_bn_imgnet[predictor].append(search_trajectory)
  else: 
    trajectories_bn_imgnet[predictor] = []
    trajectories_bn_imgnet[predictor].append(search_trajectory)

# %%
plot_optimizers(trajectories_bn_imgnet,'NAS-Bench201_ImageNet16-120')

# %% [markdown]
# <a name="zcps"></a>
# # 4. Zero Cost Proxies
#
# Zero Cost proxies allow us to *rank* models using only a single forward and backward pass of the data. Since they require much less time and compute to score models (as opposed to training them from scratch and comparing them, for example), they can be used as a cheap *proxy* to speed up black-box optimizers.
#
# In this section, we look how we can use one of the 13 Zero Cost proxies available in NASLib to *score* a model. Intuitively, the higher the score of a model, the better we expect the model to perform (this isn't always true, though - there are cases where the scores are anti-correlated with the validation performance).
#
# A perfect Zero Cost proxy would be one where its scores for models are perfectly correlated with the performance of those models, i.e., the ranking of the models by the Zero Cost proxies are the same as their ranking after they have been fully trained and evaluated.

# %%
from naslib.predictors import ZeroCost
from naslib.search_spaces import NasBench201SearchSpace
from naslib.utils import get_train_val_loaders, get_project_root
from fvcore.common.config import CfgNode
from tqdm import tqdm

# Create configs required for get_train_val_loaders
config = {
    'dataset': 'cifar10', # Dataset to loader: can be cifar100, svhn, ImageNet16-120, jigsaw, class_object, class_scene, or autoencoder (the last four are TNB101 datasets)
    'data': str(get_project_root()) + '/data', # path to naslib/data
    'search': {
        'seed': 9001, # Seed to use in the train, validation and test dataloaders
        'train_portion': 0.7, # Portion of train dataset to use as train dataset. The rest is used as validation dataset.
        'batch_size': 32, # batch size of the dataloaders
    }
}
config = CfgNode(config)

# Get the dataloaders
train_loader, val_loader, test_loader, train_transform, valid_transform = get_train_val_loaders(config)

# Sample a random NB201 graph and instantiate it
graph = NasBench201SearchSpace()
graph.sample_random_architecture()
graph.parse()

# Instantiate the ZeroCost predictor
# The Zero Cost predictors can be any of the following:
# {'epe_nas', 'fisher', 'grad_norm', 'grasp', 'jacov', 'l2_norm', 'nwot', 'plain', 'snip', 'synflow', 'zen', 'flops', 'params'}

zc_pred = 'plain'
zc_predictor = ZeroCost(method_type=zc_pred)
score = zc_predictor.query(graph=graph, dataloader=train_loader)

print(f'Score of model for Zero Cost predictor {zc_pred}: {score}')
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /content/NASLib/naslib/data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting /content/NASLib/naslib/data/cifar-10-python.tar.gz to /content/NASLib/naslib/data
# Files already downloaded and verified
# Score of model for Zero Cost predictor plain: 0.09085417538881302

# %% [markdown]
# Let's now try scoring the same model with all the Zero Cost proxies. Remember that it only makes sense to compare between the scores of different models of a given proxy.

# %%
# Instantiate the ZeroCost predictor
# The Zero Cost predictors can be any of the following:
zc_predictors = ['epe_nas', 'fisher', 'grad_norm', 'grasp', 'jacov', 'l2_norm', 'nwot', 'plain', 'snip', 'synflow', 'zen', 'flops', 'params']

print('Scores of model')
for zc_pred in zc_predictors:
    zc_predictor = ZeroCost(method_type=zc_pred)
    score = zc_predictor.query(graph=graph, dataloader=train_loader)
    print(f'{zc_pred}: {score:3f}')
# Out:
# Scores of model
# epe_nas: 164.107765
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py:1053: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# fisher: 0.016750
# grad_norm: 4.093495
# grasp: -0.155474
# jacov: -732.195878
# l2_norm: 78.622498
# nwot: 305.624134
# plain: 0.115587
# snip: 5.831100
# synflow: 25.187156
# zen: 25.058960
# flops: 14.886592
# params: 0.101306

# %% [markdown]
# Now that we have seen all the Zero Cost proxies in action, let's compute the *rank correlation* between the proxy scores of a few models and their validation performance. The higher the correlation, the better the proxy.

# %%
from naslib.search_spaces.core import Metric
from naslib.utils import compute_scores, get_dataset_api

# Sample 50 random architectures, query their performances
n_graphs = 50
models = []
val_accs = []
zc_scores = []

print('Loading NAS-Bench-201 API...')
api = get_dataset_api('nasbench201', 'cifar10')

print(f'Sampling {n_graphs} NAS-Bench-201 models...')
for _ in tqdm(range(n_graphs)):
    graph = NasBench201SearchSpace()
    graph.sample_random_architecture()
    graph.parse()

    models.append(graph)

print('Querying validation performance for all models')
for graph in tqdm(models):
    acc = graph.query(metric=Metric.VAL_ACCURACY, dataset='cifar10', dataset_api=api)
    val_accs.append(acc)


print('Scoring the models using Zero Cost predictor (jacov)')
zc_predictor = ZeroCost(method_type='jacov')

########## START TODO ############

# Score the models
# Add the scores to zc_scores 

########### END TODO #############

# We now compute the correlation between val_accs (ground truth) and zc_scores (proxy scores)
correlations = compute_scores(ytest=val_accs, test_pred=zc_scores)

# Extract the results
kendalltau_corr = correlations['kendalltau']
spearman_corr = correlations['spearman']
pearson_corr = correlations['pearson']

print('*'*50)
print('Validation accuracies: ', val_accs)
print()
print('Zero Cost predictor scores: ', zc_scores)
print('*'*50)
print('Correlations between validation accuracies (ground truth) and Zero Cost predictor scores (prediction): ')
print('Kendall Tau correlation:', kendalltau_corr)
print('Spearman correlation:', spearman_corr)
print('Pearson correlation:', pearson_corr)

# %% [markdown]
# ## Zero Cost Proxy Benchmarks
#
# Much like NAS-Benchmark APIs, we have introduced Zero Cost Benchmark APIs, which lets you query instantly the Zero Cost proxy scores for a given model in a search space. Once again, the idea is to speed-up NAS research. If a black-box optimizer you want to write leverages Zero Cost proxies, for example, you could leverage the Zero Cost Benchmarks to run the experiments much faster by simply querying them for the scores instead of the scoring the models using the Zero Cost proxies.
#
# We have already downloaded the Zero Cost Benchmark API for NAS-Bench-201, which has the scores for all 15625 models evaluated for all three datasets (CIFAR-10, CIFAR-100 and ImageNet16-120) using all 13 Zero Cost proxies.

# %% [markdown]
# Let's now query the benchmark API

# %%
from naslib.utils import get_zc_benchmark_api

# Load the Zero Cost Benchmark API for NAS-Bench-201 CIFAR-10
zc_api = get_zc_benchmark_api('nasbench201', 'cifar10')
graph = models[0]

# Use the Zero Cost Benchmark to get the score for the model for a particular ZC proxy
pred = 'grasp'
spec = graph.get_hash()
score = zc_api[str(spec)][pred]['score']
time_to_compute = zc_api[str(spec)][pred]['time']

print(f'All the data available in the Zero Cost benchmark for model {spec}: ')
print(zc_api[str(spec)][pred])
print(f'Score of model with spec {spec} for Zero Cost proxies {pred}: {score}')
print(f'Time taken to compute the score for the model: {time_to_compute:.2f}s')
# Out:
# All the data available in the Zero Cost benchmark for model (2, 0, 0, 3, 0, 0):
# {'score': -0.016125619411468506, 'time': 2.279462897218764}
# Score of model with spec (2, 0, 0, 3, 0, 0) for Zero Cost proxies grasp: -0.016125619411468506
# Time taken to compute the score for the model: 2.28s

# %%
zc_scores = {pred: [] for pred in zc_predictors} # Just dictionary of an empty list for each predictor
print('zc_scores:', zc_scores)

print('Querying Zero Cost Benchmark for scores')
for graph in tqdm(models):
    spec = graph.get_hash()

    # Get the score for this model for all the Zero Cost proxies
    for pred in zc_predictors:
        score = zc_api[str(spec)][pred]['score']
        zc_scores[pred].append (score)

# Print the Zero Cost values for the first 5 models
for pred in zc_predictors:
    print(pred, zc_scores[pred][:5])

kt_corrs = {}
# Compute the rank correlation for each of the predictors
for pred in zc_predictors:
    correlations = compute_scores(ytest=val_accs, test_pred=zc_scores[pred])
    kendalltau_corr = correlations['kendalltau']
    kt_corrs[pred] = kendalltau_corr

print('Kendall-Tau correlations for all the predictors:')
print(kt_corrs)
# Sort the predictors from best to worst for these models
kt_corrs_list = [(pred, score) for pred, score in kt_corrs.items()]
kt_corrs_list = sorted(kt_corrs_list, reverse=True, key=lambda pred_score_tuple: pred_score_tuple[1])

print('ZC predictors ranked (best to worst):')
for idx, (pred, score) in enumerate(kt_corrs_list):
    print(f'#{idx+1}', pred, score)
# Out:
# 100%|██████████| 50/50 [00:00<00:00, 8909.64it/s]
# zc_scores: {'epe_nas': [], 'fisher': [], 'grad_norm': [], 'grasp': [], 'jacov': [], 'l2_norm': [], 'nwot': [], 'plain': [], 'snip': [], 'synflow': [], 'zen': [], 'flops': [], 'params': []}
# Querying Zero Cost Benchmark for scores
# epe_nas [1292.8213521234534, 1677.4133181362522, 771.6244256973021, 1737.454440152671, 1573.3680969091486]
# fisher [0.0032408733386546373, 0.6351345181465149, 0.036273304373025894, 0.04645204544067383, 1.5173672437667847]
# grad_norm [1.9650213718414307, 72.5101547241211, 7.580556869506836, 16.29119300842285, 126.30833435058594]
# grasp [-0.016125619411468506, -3.2642059326171875, -0.06577873229980469, 4.319438457489014, 157.290771484375]
# jacov [-72.90912838633159, -65.15828505076317, -311.63863660167726, -65.98522306098099, -65.11022856424916]
# l2_norm [129.5747528076172, 231.27603149414062, 78.764892578125, 180.98062133789062, 282.43365478515625]
# nwot [756.8241446485636, 789.6434823031072, 611.1394665263265, 782.2980597435335, 818.9739002527507]
# plain [0.06447502225637436, 0.11616043746471405, 0.23372536897659302, 0.17150962352752686, -0.022408679127693176]
# snip [3.450115919113159, 117.0306396484375, 16.48707389831543, 35.3172721862793, 161.0484161376953]
# synflow [68.96618744961702, 65.32086886367614, 14.727328236083682, 49.8678214509082, 85.10796542468181]
# zen [149.5738067626953, 63.220680236816406, 6.479037284851074, 51.21070098876953, 105.7850341796875]
# flops [48.125632, 58.140352, 45.053632, 22.320832, 93.959872]
# params [0.344346, 0.400346, 0.316346, 0.157306, 0.643386]
# Kendall-Tau correlations for all the predictors:
# {'epe_nas': 0.34530612244897957, 'fisher': 0.38285714285714284, 'grad_norm': 0.43673469387755104, 'grasp': 0.36979591836734693, 'jacov': 0.48244897959183675, 'l2_norm': 0.5510204081632653, 'nwot': 0.5853061224489795, 'plain': -0.40244897959183673, 'snip': 0.43673469387755104, 'synflow': 0.58146186962603, 'zen': 0.2816326530612245, 'flops': 0.4946655921380456, 'params': 0.5210917321575367}
# ZC predictors ranked (best to worst):
# #1 nwot 0.5853061224489795
# #2 synflow 0.58146186962603
# #3 l2_norm 0.5510204081632653
# #4 params 0.5210917321575367
# #5 flops 0.4946655921380456
# #6 jacov 0.48244897959183675
# #7 grad_norm 0.43673469387755104
# #8 snip 0.43673469387755104
# #9 fisher 0.38285714285714284
# #10 grasp 0.36979591836734693
# #11 epe_nas 0.34530612244897957
# #12 zen 0.2816326530612245
# #13 plain -0.40244897959183673

# %% [markdown]
# # Bonus Challenge: Awesome Optimizer
#
# Blazed through the tutorial? Want an extra challenge?
#
# We ask you to write a black box optimizer that beats the RandomSearch baseline for NAS-Bench-201 for CIFAR-10, CIFAR-100 and ImageNet16-120 datasets.
#
# Given below is the skeletal code for a NASLib Black-box optimizer, with everything except its main method - new_epoch() - filled. This method is called in every step of the search of the Trainer (as seen in the run_optimizer function before) and is responsible for executing the main logic of the optimizer. E.g., the Random-Search optimizer samples a random architecture and queries its validation performance here.
#
# Remember that every query of a NAS-Benchmark for its validation performance is a substitute for training the model from scratch and evaluating its performance.
#
# In this challenge, there is only one rule: **You may query the validation performance of only ONE model in new_epoch()**.
#
# i.e., only one model shall be evaluated in every call of new_epoch(). Feel free to sample several models, and rank them, and query only the best model, for example. You are free to implement your own ideas here.

# %%
import torch

from fvcore.common.config import CfgNode

from naslib.optimizers.core.metaclasses import MetaOptimizer
from naslib.predictors.zerocost import ZeroCost
from naslib.search_spaces.core.graph import Graph
from naslib.search_spaces.core.query_metrics import Metric
from naslib.utils import get_train_val_loaders

# Import whatever else you want from NASLib

class AwesomeOptimizer(MetaOptimizer):
    """
    Implement your awesome optimizer here.

    This optimizer inherits from RandomSearch purely for convenience. Your search
    method does not have to be random at all. Feel free to write your own logic, and add 
    any new methods that you need for it.
    """

    def __init__(self, config: CfgNode):
        """
        Initialize your optimizer

        Args:
            config
        """
        super(AwesomeOptimizer, self).__init__()
        # These two lists are required
        self.sampled_archs = []
        self.history = []
        
        self.performance_metric = Metric.VAL_ACCURACY
        # You can add more properties to the config file and read them if you want
        self.dataset = config.dataset
        self.fidelity = config.search.fidelity

        # A few things that might be useful to you. Add/remove code as you wish.
        self.trainloader = get_train_val_loaders(config)[0]
        self.zerocostpredictor = ZeroCost(method_type='l2_norm')
        # self.my_awesome_property = config.my_awesome_property

        ###########################################################
        ##################### START TODO ##########################


        # Need more stuff in your initializer? Write them here!


        ##################### END TODO  ##########################
        ##########################################################


    def adapt_search_space(self, search_space: Graph, scope: str = None, dataset_api: dict = None):
        """
        This method has to be called with the search_space and the nas benchmark api before the optimizer
        can be used.

        Args:
            search_space : An instance of the search space, such as NasBench201SearchSpace()
            scope        : Relevant only for one-shot optimizers
            dataset_api  : NAS Benchmark API for the given search space
        """
        self.search_space = search_space.clone()
        self.dataset_api = dataset_api


    def new_epoch(self, epoch: int):
        """
        This method is called in every "step" of the search.

        Args:
            epoch: epoch number
        """

        # For reference, this is the code inside new_epoch in RandomSearch:

        # model = torch.nn.Module()
        # model.arch = self.search_space.clone()
        # model.arch.sample_random_architecture(dataset_api=self.dataset_api)
        # model.accuracy = model.arch.query(
        #     self.performance_metric,
        #     self.dataset,
        #     epoch=self.fidelity,
        #     dataset_api=self.dataset_api,
        # )
        # self.sampled_archs.append(model)
        # self._update_history(model)

        # All it does 

        ###########################################################
        ##################### START TODO ##########################


        # Write your logic here
        # Also feel free to write new methods in this class


        ##################### END TODO  ##########################
        ##########################################################

        self.sampled_archs.append(model) # This line is required. Add your chosen model to sampled_archs here.

    def get_final_architecture(self):
        """
        Returns the sampled architecture with the lowest validation error.
        """
        return max(self.sampled_archs, key=lambda x: x.accuracy).arch

    def train_statistics(self, report_incumbent: bool = True):

        if report_incumbent:
            best_arch = self.get_final_architecture()
        else:
            best_arch = self.sampled_archs[-1].arch

        return (
            best_arch.query(
                Metric.TRAIN_ACCURACY, self.dataset, dataset_api=self.dataset_api
            ),
            best_arch.query(
                Metric.VAL_ACCURACY, self.dataset, dataset_api=self.dataset_api
            ),
            best_arch.query(
                Metric.TEST_ACCURACY, self.dataset, dataset_api=self.dataset_api
            ),
            best_arch.query(
                Metric.TRAIN_TIME, self.dataset, dataset_api=self.dataset_api
            ),
        )

    def test_statistics(self):
        best_arch = self.get_final_architecture()
        return best_arch.query(Metric.RAW, self.dataset, dataset_api=self.dataset_api)

    def _update_history(self, child):
        """
            We want to maintain only the history of the 100 best models in self.history
            (self.sampled_archs stores the list of all models sampled.)
        """
        if len(self.history) < 100:
            self.history.append(child)
        else:
            for i, p in enumerate(self.history):
                if child.accuracy > p.accuracy:
                    self.history[i] = child
                    break

    def get_checkpointables(self):
        return {"models": self.history}
